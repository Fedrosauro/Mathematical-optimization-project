# %%
import random
import numpy as np
import PDSVRP_instance
import copy

import time

# %%
from importnb import Notebook

with Notebook():
    import heuristic as h
    import utilities as u

# %%
def SISSRs_with_initial_solution_return(instance, sigma, c_average_removed, L_max, w1, w2, w3, w4, w5, gamma, n_nearest, delta, epsilon, iter_imp, iter_max, p_min, p_max, max_unfeasible_swaps_perturb):
    s_0 = h.initial_solution_construction(instance, w1, w2, w3, w4, w5, gamma, n_nearest)
    s_curr = s_0
    s_best = s_0
    iterations_without_improvement = 0
    iteration_counter = 0
    while (iteration_counter < iter_max):
        s = h.ruin_and_recreate(instance, copy.deepcopy(s_curr), sigma, c_average_removed, L_max, w1, w2, w3, w4, w5, gamma)
        if u.cost(instance, s) < u.cost(instance, s_curr)*(1+delta):
            s_curr = h.local_search(instance, s, n_nearest)
            if u.cost(instance, s_curr) < u.cost(instance, s_best):
                s_best = s_curr
                iterations_without_improvement = 0
            else:
                iterations_without_improvement += 1
        if iterations_without_improvement >= iter_imp:
            s_curr = h.perturbate(instance, s_curr, p_min, p_max, max_unfeasible_swaps_perturb)
            iterations_without_improvement = 0
        delta = delta * epsilon
        iteration_counter+=1

    return s_0, s_best

# %%
import time
import copy
import pandas as pd

def test_robustness(repetitions, heuristic, instances,  sigma, c_average_removed, L_max, w1, w2, w3, w4, w5, gamma, n_nearest, delta, epsilon, iter_imp, iter_max, p_min, p_max, max_unfeasible_swaps_perturb):
    results = []
            
    for instance_name in instances:
        instance = PDSVRP_instance.PDSVRPInstance("instances/" + instance_name + ".txt") # Assumi che le istanze abbiano una rappresentazione stringa unica

        print("Instance: ", instance_name)
        avarage_cost = 0
        avarage_initial_cost = 0
        best_cost = None
        avarage_time = 0

        customers_served_by_drones = 0
        trucks_used = 0


        for i in range(repetitions):
            print("repetition ", i+1)
    
            start_time = time.time()
            init_sol, sol = heuristic(instance, sigma, c_average_removed, L_max, w1, w2, w3, w4, w5, gamma, n_nearest, delta, epsilon, iter_imp, iter_max, p_min, p_max, max_unfeasible_swaps_perturb)
            end_time = time.time()
            cost_heu = u.cost(instance, sol)
            cost_init_heu = u.cost(instance, init_sol)
            elapsed_time_heuristic = end_time - start_time
            avarage_time += elapsed_time_heuristic
            avarage_cost += cost_heu
            avarage_initial_cost += cost_init_heu

            print("costo trovato alla ripetizione ", i + 1, ":", cost_heu)

            if (best_cost == None or (best_cost != None and best_cost > cost_heu)):
                best_cost = cost_heu
                customers_served_by_drones = 0
                trucks_used = 0
                for drone_tour in sol[0][1]:
                    customers_served_by_drones += len(drone_tour)
                for truck_tour in sol[0][0]:
                    if len(truck_tour) > 0:
                        trucks_used += 1
                
        # Calcola la differenza percentuale dei costi
        avarage_time = avarage_time / repetitions
        avarage_cost = avarage_cost / repetitions
        avarage_initial_cost = avarage_initial_cost / repetitions

        cost_difference = ((avarage_cost - best_cost) / best_cost) * 100
        initial_cost_difference = ((avarage_initial_cost - best_cost) / best_cost) * 100
                

        N_t = [i for i in range(1,instance.N) if (instance.w[i] <=  instance.Q_d and ((instance.t_d[i] * 2) <= instance.d_end))]
        drone_eligible_customers = len(N_t)


        ################################################################

        # Memorizza i risultati
        results.append({
            "instance": instance_name,
            "best_cost": best_cost,
            "avarage_gap": cost_difference,
            "avarage_gap_initial_solution": initial_cost_difference,               
            "avarage_time": avarage_time,

            "drone_eligible_customers": drone_eligible_customers,
            "customers_served_by_drones": customers_served_by_drones,
            "trucks_used" : trucks_used,

            "repetitions": repetitions,
            "iter_imp": iter_imp,
            "iter_max": iter_max
        })
    
    return results

def save_results_to_csv(results, filename):
    df = pd.DataFrame(results)
    df.to_csv(filename, index=False)

# Definisci i metodi e le varianti
heuristic = SISSRs_with_initial_solution_return
instances = []


for customers_position in ["c", "r", "rc"]:
    for depot_position in ["c", "e", "r"]:
        instances.append("50-" + customers_position + "-1-" + depot_position)

# Esegui i test e ottieni i risultati
results = test_robustness(10, heuristic, instances, 0.3, 7.5, 7.5, 5,1,1,2,2, 0.1, 20, 0.1, 0.999975, 100, 1000, 3, 5, 9)

# Salva i risultati in un file CSV
save_results_to_csv(results, "results/medium_instances_results.csv")
# Out:
# Instance:  50-c-1-c
# repetition  1
# costo trovato alla ripetizione  1 : 85.02399799196182
# repetition  2
# costo trovato alla ripetizione  2 : 84.26881944699964
# repetition  3
# costo trovato alla ripetizione  3 : 84.27877985501948
# repetition  4
# costo trovato alla ripetizione  4 : 84.00385645988031
# repetition  5
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 93
#      90 instances = ["50-c-1-c"]
#      92 # Esegui i test e ottieni i risultati
# ---> 93 results = test_robustness(10, heuristic, instances, 0.3, 7.5, 7.5, 5,1,1,2,2, 0.1, 20, 0.1, 0.999975, 100, 1000, 3, 5, 9)
#      95 # Salva i risultati in un file CSV
#      96 save_results_to_csv(results, "results/medium_instances_results.csv")
#
# Cell In[4], line 25, in test_robustness(repetitions, heuristic, instances, sigma, c_average_removed, L_max, w1, w2, w3, w4, w5, gamma, n_nearest, delta, epsilon, iter_imp, iter_max, p_min, p_max, max_unfeasible_swaps_perturb)
#      22 print("repetition ", i+1)
#      24 start_time = time.time()
# ---> 25 init_sol, sol = heuristic(instance, sigma, c_average_removed, L_max, w1, w2, w3, w4, w5, gamma, n_nearest, delta, epsilon, iter_imp, iter_max, p_min, p_max, max_unfeasible_swaps_perturb)
#      26 end_time = time.time()
#      27 cost_heu = u.cost(instance, sol)
#
# Cell In[3], line 10, in SISSRs_with_initial_solution_return(instance, sigma, c_average_removed, L_max, w1, w2, w3, w4, w5, gamma, n_nearest, delta, epsilon, iter_imp, iter_max, p_min, p_max, max_unfeasible_swaps_perturb)
#       8 s = h.ruin_and_recreate(instance, copy.deepcopy(s_curr), sigma, c_average_removed, L_max, w1, w2, w3, w4, w5, gamma)
#       9 if u.cost(instance, s) < u.cost(instance, s_curr)*(1+delta):
# ---> 10     s_curr = h.local_search(instance, s, n_nearest)
#      11     if u.cost(instance, s_curr) < u.cost(instance, s_best):
#      12         s_best = s_curr
#
# File c:\Users\giova\Documents\Units\MathOpt\progetto\heuristic.ipynb:196, in local_search(instance, solution, n_nearest)
#     194 new_solution = u.relocate(instance, copy.deepcopy(solution), customer, neighbor, i)
#     195 if u.cost(instance, new_solution) < u.cost(instance, solution):
# --> 196     return local_search(instance, new_solution, n_nearest)
#     199 new_solution = u.swap(instance, copy.deepcopy(solution), customer, neighbor, i)
#     200 if u.cost(instance, new_solution) < u.cost(instance, solution):
#
# File c:\Users\giova\Documents\Units\MathOpt\progetto\heuristic.ipynb:196, in local_search(instance, solution, n_nearest)
#     194 new_solution = u.relocate(instance, copy.deepcopy(solution), customer, neighbor, i)
#     195 if u.cost(instance, new_solution) < u.cost(instance, solution):
# --> 196     return local_search(instance, new_solution, n_nearest)
#     199 new_solution = u.swap(instance, copy.deepcopy(solution), customer, neighbor, i)
#     200 if u.cost(instance, new_solution) < u.cost(instance, solution):
#
# File c:\Users\giova\Documents\Units\MathOpt\progetto\heuristic.ipynb:196, in local_search(instance, solution, n_nearest)
#     194 new_solution = u.relocate(instance, copy.deepcopy(solution), customer, neighbor, i)
#     195 if u.cost(instance, new_solution) < u.cost(instance, solution):
# --> 196     return local_search(instance, new_solution, n_nearest)
#     199 new_solution = u.swap(instance, copy.deepcopy(solution), customer, neighbor, i)
#     200 if u.cost(instance, new_solution) < u.cost(instance, solution):
#
# File c:\Users\giova\Documents\Units\MathOpt\progetto\heuristic.ipynb:216, in local_search(instance, solution, n_nearest)
#     214         new_solution = u.shift_t(instance, copy.deepcopy(solution), customer, i)
#     215         if u.cost(instance, new_solution) < u.cost(instance, solution):
# --> 216             return local_search(instance, new_solution, n_nearest)
#     219 for i in range(len(solution[0][1])):
#     221     for customer in solution[0][1][i]:
#
# File c:\Users\giova\Documents\Units\MathOpt\progetto\heuristic.ipynb:196, in local_search(instance, solution, n_nearest)
#     194 new_solution = u.relocate(instance, copy.deepcopy(solution), customer, neighbor, i)
#     195 if u.cost(instance, new_solution) < u.cost(instance, solution):
# --> 196     return local_search(instance, new_solution, n_nearest)
#     199 new_solution = u.swap(instance, copy.deepcopy(solution), customer, neighbor, i)
#     200 if u.cost(instance, new_solution) < u.cost(instance, solution):
#
# File c:\Users\giova\Documents\Units\MathOpt\progetto\heuristic.ipynb:201, in local_search(instance, solution, n_nearest)
#     199 new_solution = u.swap(instance, copy.deepcopy(solution), customer, neighbor, i)
#     200 if u.cost(instance, new_solution) < u.cost(instance, solution):
# --> 201     return local_search(instance, new_solution, n_nearest)
#     204 new_solution = u._2_opt(instance, copy.deepcopy(solution), customer, neighbor, i)
#     205 if u.cost(instance, new_solution) < u.cost(instance, solution):
#
# File c:\Users\giova\Documents\Units\MathOpt\progetto\heuristic.ipynb:211, in local_search(instance, solution, n_nearest)
#     209         new_solution = u.swap_x(instance, copy.deepcopy(solution), customer, neighbor, i)
#     210         if u.cost(instance, new_solution) < u.cost(instance, solution):
# --> 211             return local_search(instance, new_solution, n_nearest)
#     214 new_solution = u.shift_t(instance, copy.deepcopy(solution), customer, i)
#     215 if u.cost(instance, new_solution) < u.cost(instance, solution):
#
# File c:\Users\giova\Documents\Units\MathOpt\progetto\heuristic.ipynb:211, in local_search(instance, solution, n_nearest)
#     209         new_solution = u.swap_x(instance, copy.deepcopy(solution), customer, neighbor, i)
#     210         if u.cost(instance, new_solution) < u.cost(instance, solution):
# --> 211             return local_search(instance, new_solution, n_nearest)
#     214 new_solution = u.shift_t(instance, copy.deepcopy(solution), customer, i)
#     215 if u.cost(instance, new_solution) < u.cost(instance, solution):
#
# File c:\Users\giova\Documents\Units\MathOpt\progetto\heuristic.ipynb:216, in local_search(instance, solution, n_nearest)
#     214         new_solution = u.shift_t(instance, copy.deepcopy(solution), customer, i)
#     215         if u.cost(instance, new_solution) < u.cost(instance, solution):
# --> 216             return local_search(instance, new_solution, n_nearest)
#     219 for i in range(len(solution[0][1])):
#     221     for customer in solution[0][1][i]:
#
# File c:\Users\giova\Documents\Units\MathOpt\progetto\heuristic.ipynb:196, in local_search(instance, solution, n_nearest)
#     194 new_solution = u.relocate(instance, copy.deepcopy(solution), customer, neighbor, i)
#     195 if u.cost(instance, new_solution) < u.cost(instance, solution):
# --> 196     return local_search(instance, new_solution, n_nearest)
#     199 new_solution = u.swap(instance, copy.deepcopy(solution), customer, neighbor, i)
#     200 if u.cost(instance, new_solution) < u.cost(instance, solution):
#
# File c:\Users\giova\Documents\Units\MathOpt\progetto\heuristic.ipynb:196, in local_search(instance, solution, n_nearest)
#     194 new_solution = u.relocate(instance, copy.deepcopy(solution), customer, neighbor, i)
#     195 if u.cost(instance, new_solution) < u.cost(instance, solution):
# --> 196     return local_search(instance, new_solution, n_nearest)
#     199 new_solution = u.swap(instance, copy.deepcopy(solution), customer, neighbor, i)
#     200 if u.cost(instance, new_solution) < u.cost(instance, solution):
#
# File c:\Users\giova\Documents\Units\MathOpt\progetto\heuristic.ipynb:196, in local_search(instance, solution, n_nearest)
#     194 new_solution = u.relocate(instance, copy.deepcopy(solution), customer, neighbor, i)
#     195 if u.cost(instance, new_solution) < u.cost(instance, solution):
# --> 196     return local_search(instance, new_solution, n_nearest)
#     199 new_solution = u.swap(instance, copy.deepcopy(solution), customer, neighbor, i)
#     200 if u.cost(instance, new_solution) < u.cost(instance, solution):
#
# File c:\Users\giova\Documents\Units\MathOpt\progetto\heuristic.ipynb:194, in local_search(instance, solution, n_nearest)
#     191         return local_search(instance, new_solution, n_nearest)
#     193 else:
# --> 194     new_solution = u.relocate(instance, copy.deepcopy(solution), customer, neighbor, i)
#     195     if u.cost(instance, new_solution) < u.cost(instance, solution):
#     196         return local_search(instance, new_solution, n_nearest)
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\Lib\copy.py:146, in deepcopy(x, memo, _nil)
#     144 copier = _deepcopy_dispatch.get(cls)
#     145 if copier is not None:
# --> 146     y = copier(x, memo)
#     147 else:
#     148     if issubclass(cls, type):
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\Lib\copy.py:206, in _deepcopy_list(x, memo, deepcopy)
#     204 append = y.append
#     205 for a in x:
# --> 206     append(deepcopy(a, memo))
#     207 return y
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\Lib\copy.py:177, in deepcopy(x, memo, _nil)
#     175 if y is not x:
#     176     memo[d] = y
# --> 177     _keep_alive(x, memo) # Make sure x lives at least as long as d
#     178 return y
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\Lib\copy.py:254, in _keep_alive(x, memo)
#     244 """Keeps a reference to the object x in the memo.
#     245
#     246 Because we remember objects by their id, we have
#    (...)
#     251 the memo itself...
#     252 """
#     253 try:
# --> 254     memo[id(memo)].append(x)
#     255 except KeyError:
#     256     # aha, this is the first one :-)
#     257     memo[id(memo)]=[x]
#
# KeyboardInterrupt:
