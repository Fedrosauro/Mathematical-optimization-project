# %%
import random
import numpy as np
import PDSVRP_instance
import copy

import time

# %%
from importnb import Notebook

with Notebook():
    import heuristic as h
    import utilities as u
    from solver import PDSVRPModel
# Out:
# Requirement already satisfied: gurobipy in c:\users\giova\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (11.0.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
def SISSRs_with_initial_solution_return(instance, sigma, c_average_removed, L_max, w1, w2, w3, w4, w5, gamma, n_nearest, delta, epsilon, iter_imp, iter_max, p_min, p_max, max_unfeasible_swaps_perturb):
    s_0 = h.initial_solution_construction(instance, w1, w2, w3, w4, w5, gamma, n_nearest)
    s_curr = s_0
    s_best = s_0
    iterations_without_improvement = 0
    iteration_counter = 0
    while (iteration_counter < iter_max):
        s = h.ruin_and_recreate(instance, copy.deepcopy(s_curr), sigma, c_average_removed, L_max, w1, w2, w3, w4, w5, gamma)
        if u.cost(instance, s) < u.cost(instance, s_curr)*(1+delta):
            s_curr = h.local_search(instance, s, n_nearest)
            if u.cost(instance, s_curr) < u.cost(instance, s_best):
                s_best = s_curr
                iterations_without_improvement = 0
            else:
                iterations_without_improvement += 1
        if iterations_without_improvement >= iter_imp:
            s_curr = h.perturbate(instance, s_curr, p_min, p_max, max_unfeasible_swaps_perturb)
            iterations_without_improvement = 0
        delta = delta * epsilon
        iteration_counter+=1

    return s_0, s_best

# %%
import time
import copy
import pandas as pd

def test_solver_and_heuristic(solver, heuristic, instances,  sigma, c_average_removed, L_max, w1, w2, w3, w4, w5, gamma, n_nearest, delta, epsilon, iter_imp, iter_max, p_min, p_max, max_unfeasible_swaps_perturb):
    results = []
            
    for instance_name in instances:
        print("Solver for instance " + instance_name)
        instance = PDSVRP_instance.PDSVRPInstance("instances/" + instance_name + ".txt") # Assumi che le istanze abbiano una rappresentazione stringa unica
        
        
        s = solver(instance) 
        s.build_model()
        s.solve()
        cost_solver = s.model.objVal
        elapsed_time_solver = s.model.Runtime

        print("Heuristic")   
                # Esegui la variante
        start_time = time.time()
        init_sol, sol = heuristic(instance, sigma, c_average_removed, L_max, w1, w2, w3, w4, w5, gamma, n_nearest, delta, epsilon, iter_imp, iter_max, p_min, p_max, max_unfeasible_swaps_perturb)
        end_time = time.time()
        cost_init_heu = u.cost(instance, init_sol)
        cost_heu =u.cost(instance, sol)
        elapsed_time_heuristic = end_time - start_time
                
        # Calcola la differenza percentuale dei costi
        cost_difference = ((cost_heu - cost_solver) / cost_solver) * 100
                

        N_t = [i for i in range(1,instance.N) if (instance.w[i] <=  instance.Q_d and ((instance.t_d[i] * 2) <= instance.d_end))]
        drone_eligible_customers = len(N_t)

        customers_served_by_drones = 0
        trucks_used = 0
         
        if cost_heu < cost_solver:
            for drone_tour in sol[0][1]:
                customers_served_by_drones += len(drone_tour)
            trucks_used = len(sol[0][0])

        else:
            trucks_used = sum(1 for i in range(1, s.N) if s.x[0, i].x > 0)
            customers_served_by_drones = sum(1 for i in range(1, s.N) for k in range(s.D) if s.y[i, k].x > 0)

        ################################################################

        # Memorizza i risultati
        results.append({
            "instance": instance_name,
            "cost_solver": cost_solver,
            "cost_heuristic": cost_heu,
            "cost_heuristic_initial": cost_init_heu,               
            "cost_difference_percentage": cost_difference,
            "time_solver": elapsed_time_solver,
            "time_heuristic": elapsed_time_heuristic,

            "drone_eligible_customers": drone_eligible_customers,
            "customers_served_by_drones": customers_served_by_drones,
            "trucks_used" : trucks_used,


        })
    
    return results

def save_results_to_csv(results, filename):
    df = pd.DataFrame(results)
    df.to_csv(filename, index=False)

# Definisci i metodi e le varianti
model = PDSVRPModel
heuristic = SISSRs_with_initial_solution_return
instances = ["30-r-1-e"]

'''
for customers_position in ["c", "r", "rc"]:
    for depot_position in ["c", "e", "r"]:
        instances.append("30-" + customers_position + "-0-" + depot_position)
'''
# Esegui i test e ottieni i risultati
results = test_solver_and_heuristic(model, heuristic, instances, 0.3, 4.5, 4.5, 5,1,1,2,2, 0.1, 20, 0.1, 0.999975, 1000, 10000, 3, 3, 9)

# Salva i risultati in un file CSV
save_results_to_csv(results, "results/small_instances_results.csv")
# Out:
# Solver for instance 30-r-1-e
# Set parameter Threads to value 8
# Set parameter Presolve to value 2
# Set parameter Cuts to value 3
# Set parameter TimeLimit to value 3600
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-1165G7 @ 2.80GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 1026 rows, 2010 columns and 8348 nonzeros
# Model fingerprint: 0x2bcb38c2
# Variable types: 960 continuous, 1050 integer (1050 binary)
# Coefficient statistics:
#   Matrix range     [1e-02, 1e+03]
#   Objective range  [1e-01, 4e+01]
#   Bounds range     [1e+00, 1e+03]
#   RHS range        [1e+00, 1e+03]
# Presolve removed 30 rows and 521 columns
# Presolve time: 0.05s
# Presolved: 996 rows, 1489 columns, 13088 nonzeros
# Variable types: 495 continuous, 994 integer (994 binary)
# Root relaxation presolve removed 1 rows and 0 columns
# Root relaxation presolved: 995 rows, 1489 columns, 13028 nonzeros
#
#
# Root relaxation: objective 7.383158e+01, 210 iterations, 0.03 seconds (0.02 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   73.83158    0   37          -   73.83158      -     -    0s
# H    0     0                     450.0967524   73.83158  83.6%     -    0s
# H    0     0                     221.7306917  101.04001  54.4%     -    0s
# H    0     0                     187.4141197  101.04001  46.1%     -    0s
#      0     0  105.99402    0   30  187.41412  105.99402  43.4%     -    0s
#      0     0  105.99402    0   32  187.41412  105.99402  43.4%     -    0s
#      0     0  105.99402    0   32  187.41412  105.99402  43.4%     -    0s
# H    0     0                     187.4034580  106.10935  43.4%     -    0s
#      0     0  106.10935    0   40  187.40346  106.10935  43.4%     -    0s
#      0     0  108.08337    0   63  187.40346  108.08337  42.3%     -    0s
#      0     0  110.79233    0   60  187.40346  110.79233  40.9%     -    1s
#      0     0  111.02378    0   64  187.40346  111.02378  40.8%     -    1s
#      0     0  111.02378    0   64  187.40346  111.02378  40.8%     -    1s
# H    0     0                     186.8289662  111.02378  40.6%     -    1s
# H    0     0                     186.6583850  113.97085  38.9%     -    1s
# H    0     0                     185.9333850  113.97085  38.7%     -    1s
# H    0     0                     168.6962051  113.97085  32.4%     -    1s
#      0     0  113.97085    0   46  168.69621  113.97085  32.4%     -    1s
#      0     0  114.11739    0   48  168.69621  114.11739  32.4%     -    1s
# H    0     0                     168.5198205  114.11739  32.3%     -    1s
# H    0     0                     164.6326587  117.32579  28.7%     -    1s
#      0     0  117.32579    0   47  164.63266  117.32579  28.7%     -    1s
#      0     0  117.80837    0   43  164.63266  117.80837  28.4%     -    1s
# H    0     0                     160.1831669  118.24655  26.2%     -    2s
#      0     0  118.24655    0   57  160.18317  118.24655  26.2%     -    2s
#      0     0  118.66051    0   57  160.18317  118.66051  25.9%     -    2s
#      0     0  118.66051    0   60  160.18317  118.66051  25.9%     -    2s
#      0     0  119.53414    0   50  160.18317  119.53414  25.4%     -    2s
# H    0     0                     145.2217133  119.56934  17.7%     -    2s
# H    0     0                     134.7717133  119.56934  11.3%     -    2s
#      0     0  119.56934    0   52  134.77171  119.56934  11.3%     -    2s
#      0     0  119.74670    0   38  134.77171  119.74670  11.1%     -    3s
#      0     0  119.74670    0   38  134.77171  119.74670  11.1%     -    3s
#      0     0  119.74670    0   38  134.77171  119.74670  11.1%     -    3s
# H    0     0                     129.4717133  119.74724  7.51%     -    3s
# H    0     0                     126.4488345  119.74724  5.30%     -    3s
#      0     0  119.74724    0   37  126.44883  119.74724  5.30%     -    3s
#      0     0  119.74724    0   54  126.44883  119.74724  5.30%     -    4s
#      0     0  119.74724    0   54  126.44883  119.74724  5.30%     -    4s
#      0     0  119.74724    0   20  126.44883  119.74724  5.30%     -    4s
#      0     0  119.74724    0   38  126.44883  119.74724  5.30%     -    4s
#      0     0  119.74724    0   38  126.44883  119.74724  5.30%     -    4s
#      0     0  119.74724    0   38  126.44883  119.74724  5.30%     -    4s
#      0     0  119.74724    0   38  126.44883  119.74724  5.30%     -    4s
#      0     0  119.74724    0   38  126.44883  119.74724  5.30%     -    4s
#      0     2  119.74790    0   38  126.44883  119.74790  5.30%     -    4s
#     47    58  120.13670    7   43  126.44883  119.76805  5.28%  15.8    5s
# H  385   217                     122.2507806  119.76934  2.03%   8.5    5s
#
# Cutting planes:
#   Learned: 6
#   Gomory: 25
#   Lift-and-project: 53
#   Cover: 4
#   Implied bound: 31
#   Projected implied bound: 2
#   MIR: 50
#   StrongCG: 3
#   Flow cover: 192
#   Inf proof: 1
#   Zero half: 33
#   RLT: 11
#   Relax-and-lift: 14
#
# Explored 5423 nodes (57396 simplex iterations) in 8.55 seconds (4.46 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 10: 122.251 126.449 129.472 ... 168.696
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.222507806275e+02, best bound 1.222507806275e+02, gap 0.0000%
# Heuristic
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 83
#      77 '''
#      78 for customers_position in ["c", "r", "rc"]:
#      79     for depot_position in ["c", "e", "r"]:
#      80         instances.append("30-" + customers_position + "-0-" + depot_position)
#      81 '''
#      82 # Esegui i test e ottieni i risultati
# ---> 83 results = test_solver_and_heuristic(model, heuristic, instances, 0.3, 4.5, 4.5, 5,1,1,2,2, 0.1, 20, 0.1, 0.999975, 1000, 10000, 3, 3, 9)
#      85 # Salva i risultati in un file CSV
#      86 save_results_to_csv(results, "results/small_instances_results.csv")
#
# Cell In[6], line 22, in test_solver_and_heuristic(solver, heuristic, instances, sigma, c_average_removed, L_max, w1, w2, w3, w4, w5, gamma, n_nearest, delta, epsilon, iter_imp, iter_max, p_min, p_max, max_unfeasible_swaps_perturb)
#      20         # Esegui la variante
#      21 start_time = time.time()
# ---> 22 init_sol, sol = heuristic(instance, sigma, c_average_removed, L_max, w1, w2, w3, w4, w5, gamma, n_nearest, delta, epsilon, iter_imp, iter_max, p_min, p_max, max_unfeasible_swaps_perturb)
#      23 end_time = time.time()
#      24 cost_init_heu = u.cost(instance, init_sol)
#
# Cell In[4], line 10, in SISSRs_with_initial_solution_return(instance, sigma, c_average_removed, L_max, w1, w2, w3, w4, w5, gamma, n_nearest, delta, epsilon, iter_imp, iter_max, p_min, p_max, max_unfeasible_swaps_perturb)
#       8 s = h.ruin_and_recreate(instance, copy.deepcopy(s_curr), sigma, c_average_removed, L_max, w1, w2, w3, w4, w5, gamma)
#       9 if u.cost(instance, s) < u.cost(instance, s_curr)*(1+delta):
# ---> 10     s_curr = h.local_search(instance, s, n_nearest)
#      11     if u.cost(instance, s_curr) < u.cost(instance, s_best):
#      12         s_best = s_curr
#
# File c:\Users\giova\Documents\Units\MathOpt\progetto\heuristic.ipynb:216, in local_search(instance, solution, n_nearest)
#     214         new_solution = u.shift_t(instance, copy.deepcopy(solution), customer, i)
#     215         if u.cost(instance, new_solution) < u.cost(instance, solution):
# --> 216             return local_search(instance, new_solution, n_nearest)
#     219 for i in range(len(solution[0][1])):
#     221     for customer in solution[0][1][i]:
#
# File c:\Users\giova\Documents\Units\MathOpt\progetto\heuristic.ipynb:211, in local_search(instance, solution, n_nearest)
#     209         new_solution = u.swap_x(instance, copy.deepcopy(solution), customer, neighbor, i)
#     210         if u.cost(instance, new_solution) < u.cost(instance, solution):
# --> 211             return local_search(instance, new_solution, n_nearest)
#     214 new_solution = u.shift_t(instance, copy.deepcopy(solution), customer, i)
#     215 if u.cost(instance, new_solution) < u.cost(instance, solution):
#
# File c:\Users\giova\Documents\Units\MathOpt\progetto\heuristic.ipynb:216, in local_search(instance, solution, n_nearest)
#     214         new_solution = u.shift_t(instance, copy.deepcopy(solution), customer, i)
#     215         if u.cost(instance, new_solution) < u.cost(instance, solution):
# --> 216             return local_search(instance, new_solution, n_nearest)
#     219 for i in range(len(solution[0][1])):
#     221     for customer in solution[0][1][i]:
#
# File c:\Users\giova\Documents\Units\MathOpt\progetto\heuristic.ipynb:191, in local_search(instance, solution, n_nearest)
#     189     new_solution = u._2_opt_x(instance, copy.deepcopy(solution), customer, neighbor, i)
#     190     if u.cost(instance, new_solution) < u.cost(instance, solution):
# --> 191         return local_search(instance, new_solution, n_nearest)
#     193 else:
#     194     new_solution = u.relocate(instance, copy.deepcopy(solution), customer, neighbor, i)
#
# File c:\Users\giova\Documents\Units\MathOpt\progetto\heuristic.ipynb:211, in local_search(instance, solution, n_nearest)
#     209         new_solution = u.swap_x(instance, copy.deepcopy(solution), customer, neighbor, i)
#     210         if u.cost(instance, new_solution) < u.cost(instance, solution):
# --> 211             return local_search(instance, new_solution, n_nearest)
#     214 new_solution = u.shift_t(instance, copy.deepcopy(solution), customer, i)
#     215 if u.cost(instance, new_solution) < u.cost(instance, solution):
#
# File c:\Users\giova\Documents\Units\MathOpt\progetto\heuristic.ipynb:201, in local_search(instance, solution, n_nearest)
#     199 new_solution = u.swap(instance, copy.deepcopy(solution), customer, neighbor, i)
#     200 if u.cost(instance, new_solution) < u.cost(instance, solution):
# --> 201     return local_search(instance, new_solution, n_nearest)
#     204 new_solution = u._2_opt(instance, copy.deepcopy(solution), customer, neighbor, i)
#     205 if u.cost(instance, new_solution) < u.cost(instance, solution):
#
# File c:\Users\giova\Documents\Units\MathOpt\progetto\heuristic.ipynb:211, in local_search(instance, solution, n_nearest)
#     209         new_solution = u.swap_x(instance, copy.deepcopy(solution), customer, neighbor, i)
#     210         if u.cost(instance, new_solution) < u.cost(instance, solution):
# --> 211             return local_search(instance, new_solution, n_nearest)
#     214 new_solution = u.shift_t(instance, copy.deepcopy(solution), customer, i)
#     215 if u.cost(instance, new_solution) < u.cost(instance, solution):
#
# File c:\Users\giova\Documents\Units\MathOpt\progetto\heuristic.ipynb:216, in local_search(instance, solution, n_nearest)
#     214         new_solution = u.shift_t(instance, copy.deepcopy(solution), customer, i)
#     215         if u.cost(instance, new_solution) < u.cost(instance, solution):
# --> 216             return local_search(instance, new_solution, n_nearest)
#     219 for i in range(len(solution[0][1])):
#     221     for customer in solution[0][1][i]:
#
# File c:\Users\giova\Documents\Units\MathOpt\progetto\heuristic.ipynb:204, in local_search(instance, solution, n_nearest)
#     200 if u.cost(instance, new_solution) < u.cost(instance, solution):
#     201     return local_search(instance, new_solution, n_nearest)
# --> 204 new_solution = u._2_opt(instance, copy.deepcopy(solution), customer, neighbor, i)
#     205 if u.cost(instance, new_solution) < u.cost(instance, solution):
#     206     return local_search(instance, new_solution, n_nearest)
#
# File c:\Users\giova\Documents\Units\MathOpt\progetto\utilities.ipynb:507, in _2_opt(instance, solution, customer, neighbor, tour_index)
#     504 i = min(customer_index, neighbor_index)
#     505 j = max(customer_index, neighbor_index)
# --> 507 proposed_tour = copy.deepcopy(solution[0][0][tour_index])
#     509 if (i == 0):
#     510     proposed_tour[:j+1] = proposed_tour[j::-1]
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\Lib\copy.py:146, in deepcopy(x, memo, _nil)
#     144 copier = _deepcopy_dispatch.get(cls)
#     145 if copier is not None:
# --> 146     y = copier(x, memo)
#     147 else:
#     148     if issubclass(cls, type):
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\Lib\copy.py:206, in _deepcopy_list(x, memo, deepcopy)
#     204 append = y.append
#     205 for a in x:
# --> 206     append(deepcopy(a, memo))
#     207 return y
#
# KeyboardInterrupt:
