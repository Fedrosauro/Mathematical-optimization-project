# %%
# %pip install importnb
# Out:
# Requirement already satisfied: importnb in c:\users\giova\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (2023.11.1)Note: you may need to restart the kernel to use updated packages.

# %%
import PDSVRP_instance

# %%
from importnb import Notebook
with Notebook():
    import heuristic_min_time as hmt

# %%
instance = PDSVRP_instance.PDSVRPInstance("instances/eil101.txt") # Assumi che le istanze abbiano una rappresentazione stringa unica
# Out:
# 81

# %%
hmt.SISSRs_min_time(instance, 0.3, 15.15, 15.15, 5,1,1,2,2, 0.1, 20, 0.1, 0.999975, 100, 3, 3, 10.1, 9)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 hmt.SISSRs_min_time(instance, 0.3, 15.15, 15.15, 5,1,1,2,2, 0.1, 20, 0.1, 0.999975, 100, 3, 3, 10.1, 9)
#
# File c:\Users\giova\Documents\Units\MathOpt\progetto\heuristic_min_time.ipynb:324, in SISSRs_min_time(instance, sigma, c_average_removed, L_max, w1, w2, w3, w4, w5, gamma, n_nearest, delta, epsilon, iter_imp, iter_max, p_min, p_max, max_unfeasible_swaps_perturb)
#       1 {
#       2  "cells": [
#       3   {
#       4    "cell_type": "code",
#       5    "execution_count": 54,
#       6    "metadata": {},
#       7    "outputs": [],
#       8    "source": [
#       9     "import random\n",
#      10     "import numpy as np\n",
#      11     "import PDSVRP_instance\n",
#      12     "import copy"
#      13    ]
#      14   },
#      15   {
#      16    "cell_type": "code",
#      17    "execution_count": 55,
#      18    "metadata": {},
#      19    "outputs": [],
#      20    "source": [
#      21     "from importnb import Notebook\n",
#      22     "\n",
#      23     "with Notebook():\n",
#      24     "    import utilities as u"
#      25    ]
#      26   },
#      27   {
#      28    "cell_type": "code",
#      29    "execution_count": 56,
#      30    "metadata": {},
#      31    "outputs": [],
#      32    "source": [
#      33     "def sweep_removal_operator(instance, solution, sigma):\n",
#      34     "    c_drones = u.get_drone_customers(solution[0][1])\n",
#      35     "    nbSweept = random.randint(0,int(len(c_drones) * sigma))\n",
#      36     "\n",
#      37     "    grad_seed = random.randint(0, 359)\n",
#      38     "    c_drones = u.sort_by_angular(instance.coordinates, c_drones, grad_seed)\n",
#      39     "    for c in c_drones:\n",
#      40     "        if (len(solution[1]) < nbSweept):\n",
#      41     "\n",
#      42     "            #inlcude tour_index calculation inside \"remove_drone_customer, params: solution[0][1], c\"\n",
#      43     "            tour_index = next((index for index, drone_tour in enumerate(solution[0][1]) if c in drone_tour), -1)\n",
#      44     "            solution[0][1][tour_index], solution[1] = u.remove_drone_customer(solution[0][1][tour_index], solution[1], c)\n",
#      45     "                               \n",
#      46     "\n",
#      47     "    return solution"
#      48    ]
#      49   },
#      50   {
#      51    "cell_type": "code",
#      52    "execution_count": 57,
#      53    "metadata": {},
#      54    "outputs": [],
#      55    "source": [
#      56     "def random_drone_customer_removal(solution, sigma):\n",
#      57     "    #print(\"solution befor rand remove drones\", solution)\n",
#      58     "    c_drones = u.get_drone_customers(solution[0][1])\n",
#      59     "    q = random.randint(0,int(len(c_drones) * sigma))\n",
#      60     "    \n",
#      61     "    \n",
#      62     "    while (len(solution[1]) < q):\n",
#      63     "        customer_to_remove = random.choice(c_drones)\n",
#      64     "\n",
#      65     "        c_drones.remove(customer_to_remove)\n",
#      66     "        tour_index = next((index for index, drone_tour in enumerate(solution[0][1]) if customer_to_remove in drone_tour), -1)\n",
#      67     "        solution[0][1][tour_index], solution[1] = u.remove_drone_customer(solution[0][1][tour_index], solution[1], customer_to_remove)\n",
#      68     "\n",
#      69     "    return solution"
#      70    ]
#      71   },
#      72   {
#      73    "cell_type": "code",
#      74    "execution_count": 58,
#      75    "metadata": {},
#      76    "outputs": [],
#      77    "source": [
#      78     "def string_removal(instance, solution, c_average_removed, L_max): \n",
#      79     "    l_s_max = u.max_string_length(solution[0][0], L_max)\n",
#      80     "    k_s = u.n_strings_to_remove(c_average_removed, l_s_max)\n",
#      81     "    \n",
#      82     "    c_seed = random.randint(1, instance.N - 1)\n",
#      83     "\n",
#      84     "    R = []\n",
#      85     "\n",
#      86     "    c_adj = u.sort_by_euclidean_distance(instance.distances, c_seed)\n",
#      87     "\n",
#      88     "    for c in c_adj:\n",
#      89     "        if len(R) < k_s:\n",
#      90     "            if any(c in truck_tour for truck_tour in solution[0][0]):\n",
#      91     "                if c not in solution[1]:\n",
#      92     "                    tour_index = next((index for index, truck_tour in enumerate(solution[0][0]) if c in truck_tour), -1)\n",
#      93     "                    if tour_index not in R:\n",
#      94     "                        l = u.string_to_remove_length(l_s_max, solution[0][0][tour_index])\n",
#      95     "                        \n",
#      96     "                        solution[0][0][tour_index], solution[1] = u.remove_string(solution[0][0][tour_index], l, c, solution[1])\n",
#      97     "                        R.append(tour_index)\n",
#      98     "            elif any(c in drone_tour for drone_tour in solution[0][1]):\n",
#      99     "                if c not in solution[1]:\n",
#     100     "                    tour_index = next((index for index, drone_tour in enumerate(solution[0][1]) if c in drone_tour), -1)\n",
#     101     "                    solution[0][1][tour_index], solution[1] = u.remove_drone_customer(solution[0][1][tour_index], solution[1], c)\n",
#     102     "\n",
#     103     "\n",
#     104     "    return solution"
#     105    ]
#     106   },
#     107   {
#     108    "cell_type": "markdown",
#     109    "metadata": {},
#     110    "source": [
#     111     "##### First modification"
#     112    ]
#     113   },
#     114   {
#     115    "cell_type": "code",
#     116    "execution_count": 59,
#     117    "metadata": {},
#     118    "outputs": [],
#     119    "source": [
#     120     "def recreate_min_time(instance, solution, w1, w2, w3, w4, w5, gamma):\n",
#     121     "    solution[1] = u.sort_absent_customers(instance, solution, w1, w2, w3, w4, w5)\n",
#     122     "    while len(solution[1]) > 0:\n",
#     123     "        c = solution[1][0]\n",
#     124     "        pos_best = None\n",
#     125     "        makespan_best = float('inf')\n",
#     126     "        \n",
#     127     "        feasible_truck_tour_positions = u.feasible_truck_tour_positions_calculation(instance, solution[0][0], c)\n",
#     128     "\n",
#     129     "        for pos in feasible_truck_tour_positions: \n",
#     130     "            makespan_diff = u.truck_tour_time(instance.t_t, u.insert_customer(c, pos, copy.deepcopy(solution))[0][pos[0]][pos[1]]) - u.makespan(instance, copy.deepcopy(solution))\n",
#     131     "            if pos_best == None or (pos_best != None and makespan_diff < makespan_best and random.random() > (1 - gamma)):\n",
#     132     "                makespan_best = makespan_diff\n",
#     133     "                pos_best = pos\n",
#     134     "        \n",
#     135     "        if u.is_drone_eligible(instance, solution[0][1], c):\n",
#     136     "            chosen_drone = u.largest_spatial_slack_drone(instance, solution[0][1]) \n",
#     137     "            makespan_diff = u.drone_tour_time(instance.t_d, u.insert_customer(c, [1, chosen_drone, 0], copy.deepcopy(solution))[0][1][chosen_drone]) - u.makespan(instance, copy.deepcopy(solution))\n",
#     138     "            if pos_best == None or (pos_best != None and makespan_diff < makespan_best and random.random() > (1 - gamma)):\n",
#     139     "                makespan_best = makespan_diff\n",
#     140     "                pos_best = [1, chosen_drone, 0]\n",
#     141     "\n",
#     142     "        if pos_best == None:\n",
#     143     "            empty_truck_tour_index = next((index for index, truck_tour in enumerate(solution[0][0]) if len(truck_tour) == 0), -1)\n",
#     144     "            if empty_truck_tour_index == -1:\n",
#     145     "                solution[0][0].append([])\n",
#     146     "                empty_truck_tour_index = len(solution[0][0]) - 1\n",
#     147     "            \n",
#     148     "            pos_best = [0, empty_truck_tour_index, 0]\n",
#     149     "        \n",
#     150     "        solution = u.insert_customer(c, pos_best, solution)\n",
#     151     "        solution[1].remove(c)\n",
#     152     "\n",
#     153     "    return solution"
#     154    ]
#     155   },
#     156   {
#     157    "cell_type": "code",
#     158    "execution_count": 60,
#     159    "metadata": {},
#     160    "outputs": [],
#     161    "source": [
#     162     "def ruin_and_recreate_min_time(instance, solution, sigma, c_average_removed, L_max, w1, w2, w3, w4, w5, gamma):\n",
#     163     "    r = random.random()\n",
#     164     "    if (r < 0.5):\n",
#     165     "        solution = sweep_removal_operator(instance, solution, sigma)\n",
#     166     "    else:\n",
#     167     "        solution = random_drone_customer_removal(solution, sigma)\n",
#     168     "\n",
#     169     "    solution = string_removal(instance, solution, c_average_removed, L_max)\n",
#     170     "\n",
#     171     "    solution = recreate_min_time(instance, solution, w1, w2, w3, w4, w5, gamma)\n",
#     172     "\n",
#     173     "    return solution\n"
#     174    ]
#     175   },
#     176   {
#     177    "cell_type": "code",
#     178    "execution_count": 61,
#     179    "metadata": {},
#     180    "outputs": [],
#     181    "source": [
#     182     "def perturbate(instance, solution, p_min, p_max, max_unfeasible_swaps):\n",
#     183     "    p = random.randint(p_min, p_max)\n",
#     184     "    swaps_executed = 0\n",
#     185     "    unfeasible_swaps = 0\n",
#     186     "    while (swaps_executed < p and unfeasible_swaps < max_unfeasible_swaps):\n",
#     187     "        c1 = random.randint(1, instance.N - 1)\n",
#     188     "        c2 = random.randint(1, instance.N - 1)\n",
#     189     "        pos1 = u.get_position(c1, solution[0])\n",
#     190     "        pos2 = u.get_position(c2, solution[0])\n",
#     191     "        if (u.is_swap_possible(instance, solution[0], c1, pos2) and u.is_swap_possible(instance, solution[0], c2, pos1)):\n",
#     192     "            solution[0][pos1[0]][pos1[1]][pos1[2]] = c2\n",
#     193     "            solution[0][pos2[0]][pos2[1]][pos2[2]] = c1\n",
#     194     "            swaps_executed += 1\n",
#     195     "            unfeasible_swaps = 0\n",
#     196     "        else:\n",
#     197     "            unfeasible_swaps += 1\n",
#     198     "\n",
#     199     "    return solution"
#     200    ]
#     201   },
#     202   {
#     203    "cell_type": "markdown",
#     204    "metadata": {},
#     205    "source": [
#     206     "##### Second modification"
#     207    ]
#     208   },
#     209   {
#     210    "cell_type": "code",
#     211    "execution_count": 69,
#     212    "metadata": {},
#     213    "outputs": [],
#     214    "source": [
#     215     "def local_search_min_time(instance, solution, n_nearest):\n",
#     216     "\n",
#     217     "    for i in range(len(solution[0][0])):\n",
#     218     "\n",
#     219     "        for customer in solution[0][0][i]:\n",
#     220     "\n",
#     221     "            neighbors = u.select_nearest_neighbors(n_nearest, instance.distances[customer])\n",
#     222     "            for neighbor in neighbors:\n",
#     223     "                neighbor_pos = u.get_position(neighbor, copy.deepcopy(solution[0]))\n",
#     224     "\n",
#     225     "                if (neighbor in u.get_truck_customers(solution[0][0])):\n",
#     226     "                    neighbor_index = next((j for j, node in enumerate(solution[0][0][i]) if node == neighbor), None)\n",
#     227     "                    \n",
#     228     "                    if neighbor_index == None:\n",
#     229     "                        t_1 = u.truck_tour_time(instance.t_t, copy.deepcopy(solution[0][0][i]))\n",
#     230     "                        t_2 = u.truck_tour_time(instance.t_t, copy.deepcopy(solution[0][neighbor_pos[0]][neighbor_pos[1]]))\n",
#     231     "                        t = max(t_1, t_2)\n",
#     232     "\n",
#     233     "                        \n",
#     234     "\n",
#     235     "\n",
#     236     "                        new_solution = u._2_opt_x(instance, copy.deepcopy(solution), customer, neighbor, i)\n",
#     237     "                        t_1_x = u.truck_tour_time(instance.t_t, copy.deepcopy(new_solution[0][0][i]))\n",
#     238     "                        t_2_x = u.truck_tour_time(instance.t_t, copy.deepcopy(new_solution[0][neighbor_pos[0]][neighbor_pos[1]]))\n",
#     239     "\n",
#     240     "                        \n",
#     241     "                        if ((t_1_x < t and t_2_x < t) or (t_1_x < t and t_2_x < t)):\n",
#     242     "                            return local_search_min_time(instance, new_solution, n_nearest)\n",
#     243     "\n",
#     244     "                    else: \n",
#     245     "                        new_solution = u.relocate(instance, copy.deepcopy(solution), customer, neighbor, i)\n",
#     246     "                        if u.total_completion_time(instance, copy.deepcopy(new_solution)) < u.total_completion_time(instance, copy.deepcopy(solution)):\n",
#     247     "                            return local_search_min_time(instance, new_solution, n_nearest)\n",
#     248     "\n",
#     249     "                        new_solution = u.swap(instance, copy.deepcopy(solution), customer, neighbor, i)\n",
#     250     "                        if u.total_completion_time(instance, copy.deepcopy(new_solution)) < u.total_completion_time(instance, copy.deepcopy(solution)):\n",
#     251     "                            return local_search_min_time(instance, new_solution, n_nearest)\n",
#     252     "\n",
#     253     "                        new_solution = u._2_opt(instance, copy.deepcopy(solution), customer, neighbor, i)\n",
#     254     "                        if u.total_completion_time(instance, copy.deepcopy(new_solution)) < u.total_completion_time(instance, copy.deepcopy(solution)):\n",
#     255     "                            return local_search_min_time(instance, new_solution, n_nearest)\n",
#     256     "\n",
#     257     "                else:\n",
#     258     "                    t_1 = u.truck_tour_time(instance.t_t, copy.deepcopy(solution[0][0][i]))\n",
#     259     "                    t_2 = u.drone_tour_time(instance.t_d, copy.deepcopy(solution[0][neighbor_pos[0]][neighbor_pos[1]]))\n",
#     260     "                    t = max(t_1, t_2)\n",
#     261     "\n",
#     262     "                    new_solution = u.swap_x(instance, copy.deepcopy(solution), customer, neighbor, i)\n",
#     263     "                    t_1_x = u.truck_tour_time(instance.t_t, copy.deepcopy(new_solution[0][0][i]))\n",
#     264     "                    t_2_x = u.drone_tour_time(instance.t_d, copy.deepcopy(new_solution[0][neighbor_pos[0]][neighbor_pos[1]]))\n",
#     265     "\n",
#     266     "                    if ((t_1_x < t and t_2_x < t) or (t_1_x < t and t_2_x < t)):\n",
#     267     "                        return local_search_min_time(instance, new_solution, n_nearest)\n",
#     268     "\n",
#     269     "\n",
#     270     "            t_old_truck_tour = u.truck_tour_time(instance.t_t, copy.deepcopy(solution[0][0][i]))\n",
#     271     "\n",
#     272     "            new_solution = u.shift_t(instance, copy.deepcopy(solution), customer, i)\n",
#     273     "            new_customer_pos = u.get_position(customer, copy.deepcopy(new_solution[0])) #new_customer_pos contiene la pos del customer che è stato spostato dal truck tour al drone tour\n",
#     274     "            t_new_drone_tour = u.drone_tour_time(instance.t_d, copy.deepcopy(new_solution[0][new_customer_pos[0]][new_customer_pos[1]]))\n",
#     275     "            \n",
#     276     "            if (t_new_drone_tour < t_old_truck_tour and new_customer_pos[0] != 0):\n",
#     277     "                return local_search_min_time(instance, new_solution, n_nearest)\n",
#     278     "\n",
#     279     "    for i in range(len(solution[0][1])):\n",
#     280     "\n",
#     281     "        for customer in solution[0][1][i]:\n",
#     282     "            \n",
#     283     "            t_old_drone_tour = u.drone_tour_time(instance.t_d, copy.deepcopy(solution[0][1][i]))\n",
#     284     "            \n",
#     285     "            new_solution = u.shift_d(instance, copy.deepcopy(solution), customer, i)\n",
#     286     "            new_customer_pos = u.get_position(customer, copy.deepcopy(new_solution[0])) #new_customer_pos contiene la pos del customer che è stato spostato dal drone tour al truck tour\n",
#     287     "            t_new_truck_tour = u.truck_tour_time(instance.t_t, copy.deepcopy(new_solution[0][new_customer_pos[0]][new_customer_pos[1]]))\n",
#     288     "            \n",
#     289     "            \n",
#     290     "            if (t_new_truck_tour < t_old_drone_tour and new_customer_pos[0] != 1):\n",
#     291     "                return local_search_min_time(instance, new_solution, n_nearest)\n",
#     292     "\n",
#     293     "    return solution\n"
#     294    ]
#     295   },
#     296   {
#     297    "cell_type": "code",
#     298    "execution_count": 63,
#     299    "metadata": {},
#     300    "outputs": [],
#     301    "source": [
#     302     "def initial_solution_construction(instance, w1, w2, w3, w4, w5, gamma, n_nearest):\n",
#     303     "    A = [c for c in range (1, instance.N)]\n",
#     304     "    solution = recreate_min_time(instance, [[[[] for _ in range(instance.h)], [[] for _ in range(instance.D)]],A], w1, w2, w3, w4, w5, gamma)\n",
#     305     "    solution = local_search_min_time(instance, solution, n_nearest)\n",
#     306     "    return solution"
#     307    ]
#     308   },
#     309   {
#     310    "cell_type": "markdown",
#     311    "metadata": {},
#     312    "source": [
#     313     "##### Third modification"
#     314    ]
#     315   },
#     316   {
#     317    "cell_type": "code",
#     318    "execution_count": 64,
#     319    "metadata": {},
#     320    "outputs": [],
#     321    "source": [
#     322     "def SISSRs_min_time(instance, sigma, c_average_removed, L_max, w1, w2, w3, w4, w5, gamma, n_nearest, delta, epsilon, iter_imp, iter_max, p_min, p_max, max_unfeasible_swaps_perturb):\n",
#     323     "    s_0 = initial_solution_construction(instance, w1, w2, w3, w4, w5, gamma, n_nearest)\n",
# --> 324     "    s_curr = s_0\n",
#     325     "    s_best = s_0\n",
#     326     "    iterations_without_improvement = 0\n",
#     327     "    iteration_counter = 0\n",
#     328     "    while (iteration_counter < iter_max):\n",
#     329     "        s = ruin_and_recreate_min_time(instance, copy.deepcopy(s_curr), sigma, c_average_removed, L_max, w1, w2, w3, w4, w5, gamma)\n",
#     330     "        if u.makespan(instance, s) < u.makespan(instance, s_curr)*(1+delta) or ((u.makespan(instance, s) == u.makespan(instance, s_curr) and u.total_completion_time(instance,s) < u.total_completion_time(instance, s_curr))):\n",
#     331     "            s_curr = local_search_min_time(instance, s, n_nearest)\n",
#     332     "            if u.makespan(instance, s_curr) < u.makespan(instance, s_best) or ((u.makespan(instance, s) == u.makespan(instance, s_best) and u.total_completion_time(instance,s) < u.total_completion_time(instance, s_best))):\n",
#     333     "                s_best = s_curr\n",
#     334     "                iterations_without_improvement = 0\n",
#     335     "            else:\n",
#     336     "                iterations_without_improvement += 1\n",
#     337     "        if iterations_without_improvement >= iter_imp:\n",
#     338     "            s_curr = perturbate(instance, s_curr, p_min, p_max, max_unfeasible_swaps_perturb)\n",
#     339     "            iterations_without_improvement = 0\n",
#     340     "        delta = delta * epsilon\n",
#     341     "        iteration_counter+=1\n",
#     342     "        #print(\"Iteration: \", iteration_counter)\n",
#     343     "        #print(\"Tempo miglior soluzione: \", u.makespan(instance, s_best))\n",
#     344     "\n",
#     345     "    return s_best"
#     346    ]
#     347   },
#     348   {
#     349    "cell_type": "code",
#     350    "execution_count": null,
#     351    "metadata": {},
#     352    "outputs": [],
#     353    "source": [
#     354     "SISSRs_min_time(PDSVRP_instance.PDSVRPInstance(\"instances/50-c-1-c.txt\"), 0.3, 4.5, 4.5, 5,1,1,2,2, 0.1, 20, 0.1, 0.999975, 100, 1000, 3, 3, 9)"
#     355    ]
#     356   }
#     357  ],
#     358  "metadata": {
#     359   "kernelspec": {
#     360    "display_name": "Python 3",
#     361    "language": "python",
#     362    "name": "python3"
#     363   },
#     364   "language_info": {
#     365    "codemirror_mode": {
#     366     "name": "ipython",
#     367     "version": 3
#     368    },
#     369    "file_extension": ".py",
#     370    "mimetype": "text/x-python",
#     371    "name": "python",
#     372    "nbconvert_exporter": "python",
#     373    "pygments_lexer": "ipython3",
#     374    "version": "3.11.9"
#     375   }
#     376  },
#     377  "nbformat": 4,
#     378  "nbformat_minor": 2
#     379 }
#
# File c:\Users\giova\Documents\Units\MathOpt\progetto\heuristic_min_time.ipynb:306, in initial_solution_construction(instance, w1, w2, w3, w4, w5, gamma, n_nearest)
#       1 {
#       2  "cells": [
#       3   {
#       4    "cell_type": "code",
#       5    "execution_count": 54,
#       6    "metadata": {},
#       7    "outputs": [],
#       8    "source": [
#       9     "import random\n",
#      10     "import numpy as np\n",
#      11     "import PDSVRP_instance\n",
#      12     "import copy"
#      13    ]
#      14   },
#      15   {
#      16    "cell_type": "code",
#      17    "execution_count": 55,
#      18    "metadata": {},
#      19    "outputs": [],
#      20    "source": [
#      21     "from importnb import Notebook\n",
#      22     "\n",
#      23     "with Notebook():\n",
#      24     "    import utilities as u"
#      25    ]
#      26   },
#      27   {
#      28    "cell_type": "code",
#      29    "execution_count": 56,
#      30    "metadata": {},
#      31    "outputs": [],
#      32    "source": [
#      33     "def sweep_removal_operator(instance, solution, sigma):\n",
#      34     "    c_drones = u.get_drone_customers(solution[0][1])\n",
#      35     "    nbSweept = random.randint(0,int(len(c_drones) * sigma))\n",
#      36     "\n",
#      37     "    grad_seed = random.randint(0, 359)\n",
#      38     "    c_drones = u.sort_by_angular(instance.coordinates, c_drones, grad_seed)\n",
#      39     "    for c in c_drones:\n",
#      40     "        if (len(solution[1]) < nbSweept):\n",
#      41     "\n",
#      42     "            #inlcude tour_index calculation inside \"remove_drone_customer, params: solution[0][1], c\"\n",
#      43     "            tour_index = next((index for index, drone_tour in enumerate(solution[0][1]) if c in drone_tour), -1)\n",
#      44     "            solution[0][1][tour_index], solution[1] = u.remove_drone_customer(solution[0][1][tour_index], solution[1], c)\n",
#      45     "                               \n",
#      46     "\n",
#      47     "    return solution"
#      48    ]
#      49   },
#      50   {
#      51    "cell_type": "code",
#      52    "execution_count": 57,
#      53    "metadata": {},
#      54    "outputs": [],
#      55    "source": [
#      56     "def random_drone_customer_removal(solution, sigma):\n",
#      57     "    #print(\"solution befor rand remove drones\", solution)\n",
#      58     "    c_drones = u.get_drone_customers(solution[0][1])\n",
#      59     "    q = random.randint(0,int(len(c_drones) * sigma))\n",
#      60     "    \n",
#      61     "    \n",
#      62     "    while (len(solution[1]) < q):\n",
#      63     "        customer_to_remove = random.choice(c_drones)\n",
#      64     "\n",
#      65     "        c_drones.remove(customer_to_remove)\n",
#      66     "        tour_index = next((index for index, drone_tour in enumerate(solution[0][1]) if customer_to_remove in drone_tour), -1)\n",
#      67     "        solution[0][1][tour_index], solution[1] = u.remove_drone_customer(solution[0][1][tour_index], solution[1], customer_to_remove)\n",
#      68     "\n",
#      69     "    return solution"
#      70    ]
#      71   },
#      72   {
#      73    "cell_type": "code",
#      74    "execution_count": 58,
#      75    "metadata": {},
#      76    "outputs": [],
#      77    "source": [
#      78     "def string_removal(instance, solution, c_average_removed, L_max): \n",
#      79     "    l_s_max = u.max_string_length(solution[0][0], L_max)\n",
#      80     "    k_s = u.n_strings_to_remove(c_average_removed, l_s_max)\n",
#      81     "    \n",
#      82     "    c_seed = random.randint(1, instance.N - 1)\n",
#      83     "\n",
#      84     "    R = []\n",
#      85     "\n",
#      86     "    c_adj = u.sort_by_euclidean_distance(instance.distances, c_seed)\n",
#      87     "\n",
#      88     "    for c in c_adj:\n",
#      89     "        if len(R) < k_s:\n",
#      90     "            if any(c in truck_tour for truck_tour in solution[0][0]):\n",
#      91     "                if c not in solution[1]:\n",
#      92     "                    tour_index = next((index for index, truck_tour in enumerate(solution[0][0]) if c in truck_tour), -1)\n",
#      93     "                    if tour_index not in R:\n",
#      94     "                        l = u.string_to_remove_length(l_s_max, solution[0][0][tour_index])\n",
#      95     "                        \n",
#      96     "                        solution[0][0][tour_index], solution[1] = u.remove_string(solution[0][0][tour_index], l, c, solution[1])\n",
#      97     "                        R.append(tour_index)\n",
#      98     "            elif any(c in drone_tour for drone_tour in solution[0][1]):\n",
#      99     "                if c not in solution[1]:\n",
#     100     "                    tour_index = next((index for index, drone_tour in enumerate(solution[0][1]) if c in drone_tour), -1)\n",
#     101     "                    solution[0][1][tour_index], solution[1] = u.remove_drone_customer(solution[0][1][tour_index], solution[1], c)\n",
#     102     "\n",
#     103     "\n",
#     104     "    return solution"
#     105    ]
#     106   },
#     107   {
#     108    "cell_type": "markdown",
#     109    "metadata": {},
#     110    "source": [
#     111     "##### First modification"
#     112    ]
#     113   },
#     114   {
#     115    "cell_type": "code",
#     116    "execution_count": 59,
#     117    "metadata": {},
#     118    "outputs": [],
#     119    "source": [
#     120     "def recreate_min_time(instance, solution, w1, w2, w3, w4, w5, gamma):\n",
#     121     "    solution[1] = u.sort_absent_customers(instance, solution, w1, w2, w3, w4, w5)\n",
#     122     "    while len(solution[1]) > 0:\n",
#     123     "        c = solution[1][0]\n",
#     124     "        pos_best = None\n",
#     125     "        makespan_best = float('inf')\n",
#     126     "        \n",
#     127     "        feasible_truck_tour_positions = u.feasible_truck_tour_positions_calculation(instance, solution[0][0], c)\n",
#     128     "\n",
#     129     "        for pos in feasible_truck_tour_positions: \n",
#     130     "            makespan_diff = u.truck_tour_time(instance.t_t, u.insert_customer(c, pos, copy.deepcopy(solution))[0][pos[0]][pos[1]]) - u.makespan(instance, copy.deepcopy(solution))\n",
#     131     "            if pos_best == None or (pos_best != None and makespan_diff < makespan_best and random.random() > (1 - gamma)):\n",
#     132     "                makespan_best = makespan_diff\n",
#     133     "                pos_best = pos\n",
#     134     "        \n",
#     135     "        if u.is_drone_eligible(instance, solution[0][1], c):\n",
#     136     "            chosen_drone = u.largest_spatial_slack_drone(instance, solution[0][1]) \n",
#     137     "            makespan_diff = u.drone_tour_time(instance.t_d, u.insert_customer(c, [1, chosen_drone, 0], copy.deepcopy(solution))[0][1][chosen_drone]) - u.makespan(instance, copy.deepcopy(solution))\n",
#     138     "            if pos_best == None or (pos_best != None and makespan_diff < makespan_best and random.random() > (1 - gamma)):\n",
#     139     "                makespan_best = makespan_diff\n",
#     140     "                pos_best = [1, chosen_drone, 0]\n",
#     141     "\n",
#     142     "        if pos_best == None:\n",
#     143     "            empty_truck_tour_index = next((index for index, truck_tour in enumerate(solution[0][0]) if len(truck_tour) == 0), -1)\n",
#     144     "            if empty_truck_tour_index == -1:\n",
#     145     "                solution[0][0].append([])\n",
#     146     "                empty_truck_tour_index = len(solution[0][0]) - 1\n",
#     147     "            \n",
#     148     "            pos_best = [0, empty_truck_tour_index, 0]\n",
#     149     "        \n",
#     150     "        solution = u.insert_customer(c, pos_best, solution)\n",
#     151     "        solution[1].remove(c)\n",
#     152     "\n",
#     153     "    return solution"
#     154    ]
#     155   },
#     156   {
#     157    "cell_type": "code",
#     158    "execution_count": 60,
#     159    "metadata": {},
#     160    "outputs": [],
#     161    "source": [
#     162     "def ruin_and_recreate_min_time(instance, solution, sigma, c_average_removed, L_max, w1, w2, w3, w4, w5, gamma):\n",
#     163     "    r = random.random()\n",
#     164     "    if (r < 0.5):\n",
#     165     "        solution = sweep_removal_operator(instance, solution, sigma)\n",
#     166     "    else:\n",
#     167     "        solution = random_drone_customer_removal(solution, sigma)\n",
#     168     "\n",
#     169     "    solution = string_removal(instance, solution, c_average_removed, L_max)\n",
#     170     "\n",
#     171     "    solution = recreate_min_time(instance, solution, w1, w2, w3, w4, w5, gamma)\n",
#     172     "\n",
#     173     "    return solution\n"
#     174    ]
#     175   },
#     176   {
#     177    "cell_type": "code",
#     178    "execution_count": 61,
#     179    "metadata": {},
#     180    "outputs": [],
#     181    "source": [
#     182     "def perturbate(instance, solution, p_min, p_max, max_unfeasible_swaps):\n",
#     183     "    p = random.randint(p_min, p_max)\n",
#     184     "    swaps_executed = 0\n",
#     185     "    unfeasible_swaps = 0\n",
#     186     "    while (swaps_executed < p and unfeasible_swaps < max_unfeasible_swaps):\n",
#     187     "        c1 = random.randint(1, instance.N - 1)\n",
#     188     "        c2 = random.randint(1, instance.N - 1)\n",
#     189     "        pos1 = u.get_position(c1, solution[0])\n",
#     190     "        pos2 = u.get_position(c2, solution[0])\n",
#     191     "        if (u.is_swap_possible(instance, solution[0], c1, pos2) and u.is_swap_possible(instance, solution[0], c2, pos1)):\n",
#     192     "            solution[0][pos1[0]][pos1[1]][pos1[2]] = c2\n",
#     193     "            solution[0][pos2[0]][pos2[1]][pos2[2]] = c1\n",
#     194     "            swaps_executed += 1\n",
#     195     "            unfeasible_swaps = 0\n",
#     196     "        else:\n",
#     197     "            unfeasible_swaps += 1\n",
#     198     "\n",
#     199     "    return solution"
#     200    ]
#     201   },
#     202   {
#     203    "cell_type": "markdown",
#     204    "metadata": {},
#     205    "source": [
#     206     "##### Second modification"
#     207    ]
#     208   },
#     209   {
#     210    "cell_type": "code",
#     211    "execution_count": 69,
#     212    "metadata": {},
#     213    "outputs": [],
#     214    "source": [
#     215     "def local_search_min_time(instance, solution, n_nearest):\n",
#     216     "\n",
#     217     "    for i in range(len(solution[0][0])):\n",
#     218     "\n",
#     219     "        for customer in solution[0][0][i]:\n",
#     220     "\n",
#     221     "            neighbors = u.select_nearest_neighbors(n_nearest, instance.distances[customer])\n",
#     222     "            for neighbor in neighbors:\n",
#     223     "                neighbor_pos = u.get_position(neighbor, copy.deepcopy(solution[0]))\n",
#     224     "\n",
#     225     "                if (neighbor in u.get_truck_customers(solution[0][0])):\n",
#     226     "                    neighbor_index = next((j for j, node in enumerate(solution[0][0][i]) if node == neighbor), None)\n",
#     227     "                    \n",
#     228     "                    if neighbor_index == None:\n",
#     229     "                        t_1 = u.truck_tour_time(instance.t_t, copy.deepcopy(solution[0][0][i]))\n",
#     230     "                        t_2 = u.truck_tour_time(instance.t_t, copy.deepcopy(solution[0][neighbor_pos[0]][neighbor_pos[1]]))\n",
#     231     "                        t = max(t_1, t_2)\n",
#     232     "\n",
#     233     "                        \n",
#     234     "\n",
#     235     "\n",
#     236     "                        new_solution = u._2_opt_x(instance, copy.deepcopy(solution), customer, neighbor, i)\n",
#     237     "                        t_1_x = u.truck_tour_time(instance.t_t, copy.deepcopy(new_solution[0][0][i]))\n",
#     238     "                        t_2_x = u.truck_tour_time(instance.t_t, copy.deepcopy(new_solution[0][neighbor_pos[0]][neighbor_pos[1]]))\n",
#     239     "\n",
#     240     "                        \n",
#     241     "                        if ((t_1_x < t and t_2_x < t) or (t_1_x < t and t_2_x < t)):\n",
#     242     "                            return local_search_min_time(instance, new_solution, n_nearest)\n",
#     243     "\n",
#     244     "                    else: \n",
#     245     "                        new_solution = u.relocate(instance, copy.deepcopy(solution), customer, neighbor, i)\n",
#     246     "                        if u.total_completion_time(instance, copy.deepcopy(new_solution)) < u.total_completion_time(instance, copy.deepcopy(solution)):\n",
#     247     "                            return local_search_min_time(instance, new_solution, n_nearest)\n",
#     248     "\n",
#     249     "                        new_solution = u.swap(instance, copy.deepcopy(solution), customer, neighbor, i)\n",
#     250     "                        if u.total_completion_time(instance, copy.deepcopy(new_solution)) < u.total_completion_time(instance, copy.deepcopy(solution)):\n",
#     251     "                            return local_search_min_time(instance, new_solution, n_nearest)\n",
#     252     "\n",
#     253     "                        new_solution = u._2_opt(instance, copy.deepcopy(solution), customer, neighbor, i)\n",
#     254     "                        if u.total_completion_time(instance, copy.deepcopy(new_solution)) < u.total_completion_time(instance, copy.deepcopy(solution)):\n",
#     255     "                            return local_search_min_time(instance, new_solution, n_nearest)\n",
#     256     "\n",
#     257     "                else:\n",
#     258     "                    t_1 = u.truck_tour_time(instance.t_t, copy.deepcopy(solution[0][0][i]))\n",
#     259     "                    t_2 = u.drone_tour_time(instance.t_d, copy.deepcopy(solution[0][neighbor_pos[0]][neighbor_pos[1]]))\n",
#     260     "                    t = max(t_1, t_2)\n",
#     261     "\n",
#     262     "                    new_solution = u.swap_x(instance, copy.deepcopy(solution), customer, neighbor, i)\n",
#     263     "                    t_1_x = u.truck_tour_time(instance.t_t, copy.deepcopy(new_solution[0][0][i]))\n",
#     264     "                    t_2_x = u.drone_tour_time(instance.t_d, copy.deepcopy(new_solution[0][neighbor_pos[0]][neighbor_pos[1]]))\n",
#     265     "\n",
#     266     "                    if ((t_1_x < t and t_2_x < t) or (t_1_x < t and t_2_x < t)):\n",
#     267     "                        return local_search_min_time(instance, new_solution, n_nearest)\n",
#     268     "\n",
#     269     "\n",
#     270     "            t_old_truck_tour = u.truck_tour_time(instance.t_t, copy.deepcopy(solution[0][0][i]))\n",
#     271     "\n",
#     272     "            new_solution = u.shift_t(instance, copy.deepcopy(solution), customer, i)\n",
#     273     "            new_customer_pos = u.get_position(customer, copy.deepcopy(new_solution[0])) #new_customer_pos contiene la pos del customer che è stato spostato dal truck tour al drone tour\n",
#     274     "            t_new_drone_tour = u.drone_tour_time(instance.t_d, copy.deepcopy(new_solution[0][new_customer_pos[0]][new_customer_pos[1]]))\n",
#     275     "            \n",
#     276     "            if (t_new_drone_tour < t_old_truck_tour and new_customer_pos[0] != 0):\n",
#     277     "                return local_search_min_time(instance, new_solution, n_nearest)\n",
#     278     "\n",
#     279     "    for i in range(len(solution[0][1])):\n",
#     280     "\n",
#     281     "        for customer in solution[0][1][i]:\n",
#     282     "            \n",
#     283     "            t_old_drone_tour = u.drone_tour_time(instance.t_d, copy.deepcopy(solution[0][1][i]))\n",
#     284     "            \n",
#     285     "            new_solution = u.shift_d(instance, copy.deepcopy(solution), customer, i)\n",
#     286     "            new_customer_pos = u.get_position(customer, copy.deepcopy(new_solution[0])) #new_customer_pos contiene la pos del customer che è stato spostato dal drone tour al truck tour\n",
#     287     "            t_new_truck_tour = u.truck_tour_time(instance.t_t, copy.deepcopy(new_solution[0][new_customer_pos[0]][new_customer_pos[1]]))\n",
#     288     "            \n",
#     289     "            \n",
#     290     "            if (t_new_truck_tour < t_old_drone_tour and new_customer_pos[0] != 1):\n",
#     291     "                return local_search_min_time(instance, new_solution, n_nearest)\n",
#     292     "\n",
#     293     "    return solution\n"
#     294    ]
#     295   },
#     296   {
#     297    "cell_type": "code",
#     298    "execution_count": 63,
#     299    "metadata": {},
#     300    "outputs": [],
#     301    "source": [
#     302     "def initial_solution_construction(instance, w1, w2, w3, w4, w5, gamma, n_nearest):\n",
#     303     "    A = [c for c in range (1, instance.N)]\n",
#     304     "    solution = recreate_min_time(instance, [[[[] for _ in range(instance.h)], [[] for _ in range(instance.D)]],A], w1, w2, w3, w4, w5, gamma)\n",
#     305     "    solution = local_search_min_time(instance, solution, n_nearest)\n",
# --> 306     "    return solution"
#     307    ]
#     308   },
#     309   {
#     310    "cell_type": "markdown",
#     311    "metadata": {},
#     312    "source": [
#     313     "##### Third modification"
#     314    ]
#     315   },
#     316   {
#     317    "cell_type": "code",
#     318    "execution_count": 64,
#     319    "metadata": {},
#     320    "outputs": [],
#     321    "source": [
#     322     "def SISSRs_min_time(instance, sigma, c_average_removed, L_max, w1, w2, w3, w4, w5, gamma, n_nearest, delta, epsilon, iter_imp, iter_max, p_min, p_max, max_unfeasible_swaps_perturb):\n",
#     323     "    s_0 = initial_solution_construction(instance, w1, w2, w3, w4, w5, gamma, n_nearest)\n",
#     324     "    s_curr = s_0\n",
#     325     "    s_best = s_0\n",
#     326     "    iterations_without_improvement = 0\n",
#     327     "    iteration_counter = 0\n",
#     328     "    while (iteration_counter < iter_max):\n",
#     329     "        s = ruin_and_recreate_min_time(instance, copy.deepcopy(s_curr), sigma, c_average_removed, L_max, w1, w2, w3, w4, w5, gamma)\n",
#     330     "        if u.makespan(instance, s) < u.makespan(instance, s_curr)*(1+delta) or ((u.makespan(instance, s) == u.makespan(instance, s_curr) and u.total_completion_time(instance,s) < u.total_completion_time(instance, s_curr))):\n",
#     331     "            s_curr = local_search_min_time(instance, s, n_nearest)\n",
#     332     "            if u.makespan(instance, s_curr) < u.makespan(instance, s_best) or ((u.makespan(instance, s) == u.makespan(instance, s_best) and u.total_completion_time(instance,s) < u.total_completion_time(instance, s_best))):\n",
#     333     "                s_best = s_curr\n",
#     334     "                iterations_without_improvement = 0\n",
#     335     "            else:\n",
#     336     "                iterations_without_improvement += 1\n",
#     337     "        if iterations_without_improvement >= iter_imp:\n",
#     338     "            s_curr = perturbate(instance, s_curr, p_min, p_max, max_unfeasible_swaps_perturb)\n",
#     339     "            iterations_without_improvement = 0\n",
#     340     "        delta = delta * epsilon\n",
#     341     "        iteration_counter+=1\n",
#     342     "        #print(\"Iteration: \", iteration_counter)\n",
#     343     "        #print(\"Tempo miglior soluzione: \", u.makespan(instance, s_best))\n",
#     344     "\n",
#     345     "    return s_best"
#     346    ]
#     347   },
#     348   {
#     349    "cell_type": "code",
#     350    "execution_count": null,
#     351    "metadata": {},
#     352    "outputs": [],
#     353    "source": [
#     354     "SISSRs_min_time(PDSVRP_instance.PDSVRPInstance(\"instances/50-c-1-c.txt\"), 0.3, 4.5, 4.5, 5,1,1,2,2, 0.1, 20, 0.1, 0.999975, 100, 1000, 3, 3, 9)"
#     355    ]
#     356   }
#     357  ],
#     358  "metadata": {
#     359   "kernelspec": {
#     360    "display_name": "Python 3",
#     361    "language": "python",
#     362    "name": "python3"
#     363   },
#     364   "language_info": {
#     365    "codemirror_mode": {
#     366     "name": "ipython",
#     367     "version": 3
#     368    },
#     369    "file_extension": ".py",
#     370    "mimetype": "text/x-python",
#     371    "name": "python",
#     372    "nbconvert_exporter": "python",
#     373    "pygments_lexer": "ipython3",
#     374    "version": "3.11.9"
#     375   }
#     376  },
#     377  "nbformat": 4,
#     378  "nbformat_minor": 2
#     379 }
#
# File c:\Users\giova\Documents\Units\MathOpt\progetto\heuristic_min_time.ipynb:248, in local_search_min_time(instance, solution, n_nearest)
#       1 {
#       2  "cells": [
#       3   {
#       4    "cell_type": "code",
#       5    "execution_count": 54,
#       6    "metadata": {},
#       7    "outputs": [],
#       8    "source": [
#       9     "import random\n",
#      10     "import numpy as np\n",
#      11     "import PDSVRP_instance\n",
#      12     "import copy"
#      13    ]
#      14   },
#      15   {
#      16    "cell_type": "code",
#      17    "execution_count": 55,
#      18    "metadata": {},
#      19    "outputs": [],
#      20    "source": [
#      21     "from importnb import Notebook\n",
#      22     "\n",
#      23     "with Notebook():\n",
#      24     "    import utilities as u"
#      25    ]
#      26   },
#      27   {
#      28    "cell_type": "code",
#      29    "execution_count": 56,
#      30    "metadata": {},
#      31    "outputs": [],
#      32    "source": [
#      33     "def sweep_removal_operator(instance, solution, sigma):\n",
#      34     "    c_drones = u.get_drone_customers(solution[0][1])\n",
#      35     "    nbSweept = random.randint(0,int(len(c_drones) * sigma))\n",
#      36     "\n",
#      37     "    grad_seed = random.randint(0, 359)\n",
#      38     "    c_drones = u.sort_by_angular(instance.coordinates, c_drones, grad_seed)\n",
#      39     "    for c in c_drones:\n",
#      40     "        if (len(solution[1]) < nbSweept):\n",
#      41     "\n",
#      42     "            #inlcude tour_index calculation inside \"remove_drone_customer, params: solution[0][1], c\"\n",
#      43     "            tour_index = next((index for index, drone_tour in enumerate(solution[0][1]) if c in drone_tour), -1)\n",
#      44     "            solution[0][1][tour_index], solution[1] = u.remove_drone_customer(solution[0][1][tour_index], solution[1], c)\n",
#      45     "                               \n",
#      46     "\n",
#      47     "    return solution"
#      48    ]
#      49   },
#      50   {
#      51    "cell_type": "code",
#      52    "execution_count": 57,
#      53    "metadata": {},
#      54    "outputs": [],
#      55    "source": [
#      56     "def random_drone_customer_removal(solution, sigma):\n",
#      57     "    #print(\"solution befor rand remove drones\", solution)\n",
#      58     "    c_drones = u.get_drone_customers(solution[0][1])\n",
#      59     "    q = random.randint(0,int(len(c_drones) * sigma))\n",
#      60     "    \n",
#      61     "    \n",
#      62     "    while (len(solution[1]) < q):\n",
#      63     "        customer_to_remove = random.choice(c_drones)\n",
#      64     "\n",
#      65     "        c_drones.remove(customer_to_remove)\n",
#      66     "        tour_index = next((index for index, drone_tour in enumerate(solution[0][1]) if customer_to_remove in drone_tour), -1)\n",
#      67     "        solution[0][1][tour_index], solution[1] = u.remove_drone_customer(solution[0][1][tour_index], solution[1], customer_to_remove)\n",
#      68     "\n",
#      69     "    return solution"
#      70    ]
#      71   },
#      72   {
#      73    "cell_type": "code",
#      74    "execution_count": 58,
#      75    "metadata": {},
#      76    "outputs": [],
#      77    "source": [
#      78     "def string_removal(instance, solution, c_average_removed, L_max): \n",
#      79     "    l_s_max = u.max_string_length(solution[0][0], L_max)\n",
#      80     "    k_s = u.n_strings_to_remove(c_average_removed, l_s_max)\n",
#      81     "    \n",
#      82     "    c_seed = random.randint(1, instance.N - 1)\n",
#      83     "\n",
#      84     "    R = []\n",
#      85     "\n",
#      86     "    c_adj = u.sort_by_euclidean_distance(instance.distances, c_seed)\n",
#      87     "\n",
#      88     "    for c in c_adj:\n",
#      89     "        if len(R) < k_s:\n",
#      90     "            if any(c in truck_tour for truck_tour in solution[0][0]):\n",
#      91     "                if c not in solution[1]:\n",
#      92     "                    tour_index = next((index for index, truck_tour in enumerate(solution[0][0]) if c in truck_tour), -1)\n",
#      93     "                    if tour_index not in R:\n",
#      94     "                        l = u.string_to_remove_length(l_s_max, solution[0][0][tour_index])\n",
#      95     "                        \n",
#      96     "                        solution[0][0][tour_index], solution[1] = u.remove_string(solution[0][0][tour_index], l, c, solution[1])\n",
#      97     "                        R.append(tour_index)\n",
#      98     "            elif any(c in drone_tour for drone_tour in solution[0][1]):\n",
#      99     "                if c not in solution[1]:\n",
#     100     "                    tour_index = next((index for index, drone_tour in enumerate(solution[0][1]) if c in drone_tour), -1)\n",
#     101     "                    solution[0][1][tour_index], solution[1] = u.remove_drone_customer(solution[0][1][tour_index], solution[1], c)\n",
#     102     "\n",
#     103     "\n",
#     104     "    return solution"
#     105    ]
#     106   },
#     107   {
#     108    "cell_type": "markdown",
#     109    "metadata": {},
#     110    "source": [
#     111     "##### First modification"
#     112    ]
#     113   },
#     114   {
#     115    "cell_type": "code",
#     116    "execution_count": 59,
#     117    "metadata": {},
#     118    "outputs": [],
#     119    "source": [
#     120     "def recreate_min_time(instance, solution, w1, w2, w3, w4, w5, gamma):\n",
#     121     "    solution[1] = u.sort_absent_customers(instance, solution, w1, w2, w3, w4, w5)\n",
#     122     "    while len(solution[1]) > 0:\n",
#     123     "        c = solution[1][0]\n",
#     124     "        pos_best = None\n",
#     125     "        makespan_best = float('inf')\n",
#     126     "        \n",
#     127     "        feasible_truck_tour_positions = u.feasible_truck_tour_positions_calculation(instance, solution[0][0], c)\n",
#     128     "\n",
#     129     "        for pos in feasible_truck_tour_positions: \n",
#     130     "            makespan_diff = u.truck_tour_time(instance.t_t, u.insert_customer(c, pos, copy.deepcopy(solution))[0][pos[0]][pos[1]]) - u.makespan(instance, copy.deepcopy(solution))\n",
#     131     "            if pos_best == None or (pos_best != None and makespan_diff < makespan_best and random.random() > (1 - gamma)):\n",
#     132     "                makespan_best = makespan_diff\n",
#     133     "                pos_best = pos\n",
#     134     "        \n",
#     135     "        if u.is_drone_eligible(instance, solution[0][1], c):\n",
#     136     "            chosen_drone = u.largest_spatial_slack_drone(instance, solution[0][1]) \n",
#     137     "            makespan_diff = u.drone_tour_time(instance.t_d, u.insert_customer(c, [1, chosen_drone, 0], copy.deepcopy(solution))[0][1][chosen_drone]) - u.makespan(instance, copy.deepcopy(solution))\n",
# ...
#     121     "    solution[1] = u.sort_absent_customers(instance, solution, w1, w2, w3, w4, w5)\n",
#     122     "    while len(solution[1]) > 0:\n",
#     123     "        c = solution[1][0]\n",
#     124     "        pos_best = None\n",
#     125     "        makespan_best = float('inf')\n",
#     126     "        \n",
#     127     "        feasible_truck_tour_positions = u.feasible_truck_tour_positions_calculation(instance, solution[0][0], c)\n",
#     128     "\n",
#     129     "        for pos in feasible_truck_tour_positions: \n",
#     130     "            makespan_diff = u.truck_tour_time(instance.t_t, u.insert_customer(c, pos, copy.deepcopy(solution))[0][pos[0]][pos[1]]) - u.makespan(instance, copy.deepcopy(solution))\n",
#     131     "            if pos_best == None or (pos_best != None and makespan_diff < makespan_best and random.random() > (1 - gamma)):\n",
#     132     "                makespan_best = makespan_diff\n",
#     133     "                pos_best = pos\n",
#     134     "        \n",
#     135     "        if u.is_drone_eligible(instance, solution[0][1], c):\n",
#     136     "            chosen_drone = u.largest_spatial_slack_drone(instance, solution[0][1]) \n",
#     137     "            makespan_diff = u.drone_tour_time(instance.t_d, u.insert_customer(c, [1, chosen_drone, 0], copy.deepcopy(solution))[0][1][chosen_drone]) - u.makespan(instance, copy.deepcopy(solution))\n",
#     138     "            if pos_best == None or (pos_best != None and makespan_diff < makespan_best and random.random() > (1 - gamma)):\n",
#     139     "                makespan_best = makespan_diff\n",
#     140     "                pos_best = [1, chosen_drone, 0]\n",
#     141     "\n",
#     142     "        if pos_best == None:\n",
#     143     "            empty_truck_tour_index = next((index for index, truck_tour in enumerate(solution[0][0]) if len(truck_tour) == 0), -1)\n",
#     144     "            if empty_truck_tour_index == -1:\n",
#     145     "                solution[0][0].append([])\n",
#     146     "                empty_truck_tour_index = len(solution[0][0]) - 1\n",
#     147     "            \n",
#     148     "            pos_best = [0, empty_truck_tour_index, 0]\n",
#     149     "        \n",
#     150     "        solution = u.insert_customer(c, pos_best, solution)\n",
#     151     "        solution[1].remove(c)\n",
#     152     "\n",
#     153     "    return solution"
#     154    ]
#     155   },
#     156   {
#     157    "cell_type": "code",
#     158    "execution_count": 20,
#     159    "metadata": {},
#     160    "outputs": [],
#     161    "source": [
#     162     "def ruin_and_recreate_min_time(instance, solution, sigma, c_average_removed, L_max, w1, w2, w3, w4, w5, gamma):\n",
#     163     "    r = random.random()\n",
#     164     "    if (r < 0.5):\n",
#     165     "        solution = sweep_removal_operator(instance, solution, sigma)\n",
#     166     "    else:\n",
#     167     "        solution = random_drone_customer_removal(solution, sigma)\n",
#     168     "\n",
#     169     "    solution = string_removal(instance, solution, c_average_removed, L_max)\n",
#     170     "\n",
#     171     "    solution = recreate_min_time(instance, solution, w1, w2, w3, w4, w5, gamma)\n",
#     172     "\n",
#     173     "    return solution\n"
#     174    ]
#     175   },
#     176   {
#     177    "cell_type": "code",
#     178    "execution_count": 21,
#     179    "metadata": {},
#     180    "outputs": [],
#     181    "source": [
#     182     "def perturbate(instance, solution, p_min, p_max, max_unfeasible_swaps):\n",
#     183     "    p = random.randint(p_min, p_max)\n",
#     184     "    swaps_executed = 0\n",
#     185     "    unfeasible_swaps = 0\n",
#     186     "    while (swaps_executed < p and unfeasible_swaps < max_unfeasible_swaps):\n",
#     187     "        c1 = random.randint(1, instance.N - 1)\n",
#     188     "        c2 = random.randint(1, instance.N - 1)\n",
#     189     "        pos1 = u.get_position(c1, solution[0])\n",
#     190     "        pos2 = u.get_position(c2, solution[0])\n",
#     191     "        if (u.is_swap_possible(instance, solution[0], c1, pos2) and u.is_swap_possible(instance, solution[0], c2, pos1)):\n",
#     192     "            solution[0][pos1[0]][pos1[1]][pos1[2]] = c2\n",
#     193     "            solution[0][pos2[0]][pos2[1]][pos2[2]] = c1\n",
#     194     "            swaps_executed += 1\n",
#     195     "            unfeasible_swaps = 0\n",
#     196     "        else:\n",
#     197     "            unfeasible_swaps += 1\n",
#     198     "\n",
#     199     "    return solution"
#     200    ]
#     201   },
#     202   {
#     203    "cell_type": "markdown",
#     204    "metadata": {},
#     205    "source": [
#     206     "##### Second modification"
#     207    ]
#     208   },
#     209   {
#     210    "cell_type": "code",
#     211    "execution_count": 22,
#     212    "metadata": {},
#     213    "outputs": [],
#     214    "source": [
#     215     "def local_search_min_time(instance, solution, n_nearest):\n",
#     216     "\n",
#     217     "    for i in range(len(solution[0][0])):\n",
#     218     "\n",
#     219     "        for customer in solution[0][0][i]:\n",
#     220     "\n",
#     221     "            neighbors = u.select_nearest_neighbors(n_nearest, instance.distances[customer])\n",
#     222     "            for neighbor in neighbors:\n",
#     223     "                neighbor_pos = u.get_position(neighbor, copy.deepcopy(solution[0]))\n",
#     224     "\n",
#     225     "                if (neighbor in u.get_truck_customers(solution[0][0])):\n",
#     226     "                    neighbor_index = next((j for j, node in enumerate(solution[0][0][i]) if node == neighbor), None)\n",
#     227     "                    \n",
#     228     "                    if neighbor_index == None:\n",
#     229     "                        t_1 = u.truck_tour_time(instance.t_t, copy.deepcopy(solution[0][0][i]))\n",
#     230     "                        t_2 = u.truck_tour_time(instance.t_t, copy.deepcopy(solution[0][neighbor_pos[0]][neighbor_pos[1]]))\n",
#     231     "                        t = max(t_1, t_2)\n",
#     232     "\n",
#     233     "                        \n",
#     234     "\n",
#     235     "\n",
#     236     "                        new_solution = u._2_opt_x(instance, copy.deepcopy(solution), customer, neighbor, i)\n",
#     237     "                        t_1_x = u.truck_tour_time(instance.t_t, copy.deepcopy(new_solution[0][0][i]))\n",
#     238     "                        t_2_x = u.truck_tour_time(instance.t_t, copy.deepcopy(new_solution[0][neighbor_pos[0]][neighbor_pos[1]]))\n",
#     239     "\n",
#     240     "                        \n",
#     241     "                        if ((t_1_x < t and t_2_x < t) or (t_1_x < t and t_2_x < t)):\n",
#     242     "                            return local_search_min_time(instance, new_solution, n_nearest)\n",
#     243     "\n",
#     244     "                    else: \n",
#     245     "                        new_solution = u.relocate(instance, copy.deepcopy(solution), customer, neighbor, i)\n",
#     246     "                        if u.total_completion_time(instance, copy.deepcopy(new_solution)) < u.total_completion_time(instance, copy.deepcopy(solution)):\n",
#     247     "                            return local_search_min_time(instance, new_solution, n_nearest)\n",
#     248     "\n",
#     249     "                        new_solution = u.swap(instance, copy.deepcopy(solution), customer, neighbor, i)\n",
#     250     "                        if u.total_completion_time(instance, copy.deepcopy(new_solution)) < u.total_completion_time(instance, copy.deepcopy(solution)):\n",
#     251     "                            return local_search_min_time(instance, new_solution, n_nearest)\n",
#     252     "\n",
#     253     "                        new_solution = u._2_opt(instance, copy.deepcopy(solution), customer, neighbor, i)\n",
# --> 254     "                        if u.total_completion_time(instance, copy.deepcopy(new_solution)) < u.total_completion_time(instance, copy.deepcopy(solution)):\n",
#     255     "                            return local_search_min_time(instance, new_solution, n_nearest)\n",
#     256     "\n",
#     257     "                else:\n",
#     258     "                    t_1 = u.truck_tour_time(instance.t_t, copy.deepcopy(solution[0][0][i]))\n",
#     259     "                    t_2 = u.drone_tour_time(instance.t_d, copy.deepcopy(solution[0][neighbor_pos[0]][neighbor_pos[1]]))\n",
#     260     "                    t = max(t_1, t_2)\n",
#     261     "\n",
#     262     "                    new_solution = u.swap_x(instance, copy.deepcopy(solution), customer, neighbor, i)\n",
#     263     "                    t_1_x = u.truck_tour_time(instance.t_t, copy.deepcopy(new_solution[0][0][i]))\n",
#     264     "                    t_2_x = u.drone_tour_time(instance.t_d, copy.deepcopy(new_solution[0][neighbor_pos[0]][neighbor_pos[1]]))\n",
#     265     "\n",
#     266     "                    if ((t_1_x < t and t_2_x < t) or (t_1_x < t and t_2_x < t)):\n",
#     267     "                        return local_search_min_time(instance, new_solution, n_nearest)\n",
#     268     "\n",
#     269     "\n",
#     270     "            t_old_truck_tour = u.truck_tour_time(instance.t_t, copy.deepcopy(solution[0][0][i]))\n",
#     271     "\n",
#     272     "            new_solution = u.shift_t(instance, copy.deepcopy(solution), customer, i)\n",
#     273     "            new_customer_pos = u.get_position(customer, copy.deepcopy(new_solution[0])) #new_customer_pos contiene la pos del customer che è stato spostato dal truck tour al drone tour\n",
#     274     "            t_new_drone_tour = u.drone_tour_time(instance.t_d, copy.deepcopy(new_solution[0][new_customer_pos[0]][new_customer_pos[1]]))\n",
#     275     "            \n",
#     276     "            if (t_new_drone_tour < t_old_truck_tour and new_customer_pos[0] != 0):\n",
#     277     "                return local_search_min_time(instance, new_solution, n_nearest)\n",
#     278     "\n",
#     279     "    for i in range(len(solution[0][1])):\n",
#     280     "\n",
#     281     "        for customer in solution[0][1][i]:\n",
#     282     "            \n",
#     283     "            t_old_drone_tour = u.drone_tour_time(instance.t_d, copy.deepcopy(solution[0][1][i]))\n",
#     284     "            \n",
#     285     "            new_solution = u.shift_d(instance, copy.deepcopy(solution), customer, i)\n",
#     286     "            new_customer_pos = u.get_position(customer, copy.deepcopy(new_solution[0])) #new_customer_pos contiene la pos del customer che è stato spostato dal drone tour al truck tour\n",
#     287     "            t_new_truck_tour = u.truck_tour_time(instance.t_t, copy.deepcopy(new_solution[0][new_customer_pos[0]][new_customer_pos[1]]))\n",
#     288     "            \n",
#     289     "            \n",
#     290     "            if (t_new_truck_tour < t_old_drone_tour and new_customer_pos[0] != 1):\n",
#     291     "                return local_search_min_time(instance, new_solution, n_nearest)\n",
#     292     "\n",
#     293     "    return solution\n"
#     294    ]
#     295   },
#     296   {
#     297    "cell_type": "code",
#     298    "execution_count": 23,
#     299    "metadata": {},
#     300    "outputs": [],
#     301    "source": [
#     302     "def initial_solution_construction(instance, w1, w2, w3, w4, w5, gamma, n_nearest):\n",
#     303     "    A = [c for c in range (1, instance.N)]\n",
#     304     "    solution = recreate_min_time(instance, [[[[] for _ in range(instance.h)], [[] for _ in range(instance.D)]],A], w1, w2, w3, w4, w5, gamma)\n",
#     305     "    solution = local_search_min_time(instance, solution, n_nearest)\n",
#     306     "    return solution"
#     307    ]
#     308   },
#     309   {
#     310    "cell_type": "markdown",
#     311    "metadata": {},
#     312    "source": [
#     313     "##### Third modification"
#     314    ]
#     315   },
#     316   {
#     317    "cell_type": "code",
#     318    "execution_count": 24,
#     319    "metadata": {},
#     320    "outputs": [],
#     321    "source": [
#     322     "def SISSRs_min_time(instance, sigma, c_average_removed, L_max, w1, w2, w3, w4, w5, gamma, n_nearest, delta, epsilon, iter_imp, iter_max, p_min, p_max, max_unfeasible_swaps_perturb):\n",
#     323     "    print(\"Iteration 0\")\n",
#     324     "    s_0 = initial_solution_construction(instance, w1, w2, w3, w4, w5, gamma, n_nearest)\n",
#     325     "    s_curr = s_0\n",
#     326     "    s_best = s_0\n",
#     327     "    iterations_without_improvement = 0\n",
#     328     "    iteration_counter = 0\n",
#     329     "    while (iteration_counter < iter_max):\n",
#     330     "        s = ruin_and_recreate_min_time(instance, copy.deepcopy(s_curr), sigma, c_average_removed, L_max, w1, w2, w3, w4, w5, gamma)\n",
#     331     "        if u.makespan(instance, s) < u.makespan(instance, s_curr)*(1+delta) or ((u.makespan(instance, s) == u.makespan(instance, s_curr) and u.total_completion_time(instance,s) < u.total_completion_time(instance, s_curr))):\n",
#     332     "            s_curr = local_search_min_time(instance, s, n_nearest)\n",
#     333     "            if u.makespan(instance, s_curr) < u.makespan(instance, s_best) or ((u.makespan(instance, s) == u.makespan(instance, s_best) and u.total_completion_time(instance,s) < u.total_completion_time(instance, s_best))):\n",
#     334     "                s_best = s_curr\n",
#     335     "                iterations_without_improvement = 0\n",
#     336     "            else:\n",
#     337     "                iterations_without_improvement += 1\n",
#     338     "        if iterations_without_improvement >= iter_imp:\n",
#     339     "            s_curr = perturbate(instance, s_curr, p_min, p_max, max_unfeasible_swaps_perturb)\n",
#     340     "            iterations_without_improvement = 0\n",
#     341     "        delta = delta * epsilon\n",
#     342     "        iteration_counter+=1\n",
#     343     "        print(\"Iteration: \", iteration_counter)\n",
#     344     "        print(\"Tempo miglior soluzione: \", u.makespan(instance, s_best))\n",
#     345     "\n",
#     346     "    return s_best"
#     347    ]
#     348   },
#     349   {
#     350    "cell_type": "code",
#     351    "execution_count": 12,
#     352    "metadata": {},
#     353    "outputs": [],
#     354    "source": [
#     355     "#SISSRs_min_time(PDSVRP_instance.PDSVRPInstance(\"instances/50-c-1-c.txt\"), 0.3, 4.5, 4.5, 5,1,1,2,2, 0.1, 20, 0.1, 0.999975, 100, 1000, 3, 3, 9)"
#     356    ]
#     357   }
#     358  ],
#     359  "metadata": {
#     360   "kernelspec": {
#     361    "display_name": "Python 3",
#     362    "language": "python",
#     363    "name": "python3"
#     364   },
#     365   "language_info": {
#     366    "codemirror_mode": {
#     367     "name": "ipython",
#     368     "version": 3
#     369    },
#     370    "file_extension": ".py",
#     371    "mimetype": "text/x-python",
#     372    "name": "python",
#     373    "nbconvert_exporter": "python",
#     374    "pygments_lexer": "ipython3",
#     375    "version": "3.11.9"
#     376   }
#     377  },
#     378  "nbformat": 4,
#     379  "nbformat_minor": 2
#     380 }
#
# File c:\Users\giova\Documents\Units\MathOpt\progetto\utilities.ipynb:507, in _2_opt(instance, solution, customer, neighbor, tour_index)
#     504 i = min(customer_index, neighbor_index)
#     505 j = max(customer_index, neighbor_index)
# --> 507 proposed_tour = copy.deepcopy(solution[0][0][tour_index])
#     509 if (i == 0):
#     510     proposed_tour[:j+1] = proposed_tour[j::-1]
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\Lib\copy.py:146, in deepcopy(x, memo, _nil)
#     144 copier = _deepcopy_dispatch.get(cls)
#     145 if copier is not None:
# --> 146     y = copier(x, memo)
#     147 else:
#     148     if issubclass(cls, type):
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\Lib\copy.py:206, in _deepcopy_list(x, memo, deepcopy)
#     204 append = y.append
#     205 for a in x:
# --> 206     append(deepcopy(a, memo))
#     207 return y
#
# KeyboardInterrupt:
