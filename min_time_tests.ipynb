# %%
# %pip install importnb
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import PDSVRP_instance

# %%
from importnb import Notebook
with Notebook():
    import heuristic_min_time as hmt

# %%
instance = PDSVRP_instance.PDSVRPInstance("instances/eil101.txt") # Assumi che le istanze abbiano una rappresentazione stringa unica
N_t = [i for i in range(1,instance.N) if (instance.w[i] <=  instance.Q_d and ((instance.t_d[i] * 2) <= instance.d_end))]
drone_eligible_customers = len(N_t)
print(drone_eligible_customers)
# Out:
# 81

# %%
hmt.SISSRs_min_time(instance, 0.3, 15.15, 15.15, 5,1,1,2,2, 0.1, 20, 0.1, 0.999975, 100, 1000, 3, 10.1, 9)
# Out:
# Iteration:  1
# Tempo miglior soluzione:  24.52399999999999
# Iteration:  2
# Tempo miglior soluzione:  24.52399999999999
# Iteration:  3
# Tempo miglior soluzione:  24.52399999999999
# Iteration:  4
# Tempo miglior soluzione:  24.52399999999999
# Iteration:  5
# Tempo miglior soluzione:  24.52399999999999
# Iteration:  6
# Tempo miglior soluzione:  24.52399999999999
# Iteration:  7
# Tempo miglior soluzione:  24.52399999999999
# Iteration:  8
# Tempo miglior soluzione:  24.52399999999999
# Iteration:  9
# Tempo miglior soluzione:  24.52399999999999
# Iteration:  10
# Tempo miglior soluzione:  24.52399999999999
# Iteration:  11
# Tempo miglior soluzione:  24.52399999999999
# Iteration:  12
# Tempo miglior soluzione:  24.52399999999999
# Iteration:  13
# Tempo miglior soluzione:  24.52399999999999
# Iteration:  14
# Tempo miglior soluzione:  24.52399999999999
# Iteration:  15
# Tempo miglior soluzione:  24.52399999999999
# Iteration:  16
# Tempo miglior soluzione:  24.52399999999999
# ...
